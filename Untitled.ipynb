# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os,cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#matplotlib을 통해 보여줄 그래프의 크기를 직접 지정해 준것.
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import tensorflow as tf

from keras.utils import np_utils
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
from keras.models import Sequential
from keras.layers import *
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
import os
data_path = './Input/CK+48'
file_list = os.listdir(data_path)
file_list.remove('.DS_Store')
print("file list:",file_list)

# Any results you write to the current directory are saved as output

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.datasets import make_classification
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

#디렉토리에서 이미지를 추출하기

num_epoch=10

img_data_list=[]

labels = []
labeled = 0
img_count = 0
#우리가 파일을 만든 순서가 아닌 컴퓨터가 지가 읽는 순서대로 파일을 불러옴.
for dataset in file_list:
    img_one_cat_list = []
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.        
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        input_img_resize=cv2.resize(input_img,(48,48),interpolation=cv2.INTER_AREA)
        img_data_list.append(input_img_resize)
        img_one_cat_list.append(input_img_resize)
    #라벨링 넘파이 배열 생성 
    for label in range(len(img_one_cat_list)):
        labels.append(labeled)

    labeled += 1

img_data = np.array(img_data_list)
labels = np.array(labels)

#이미지 데이터 정규화

img_data = img_data.astype('float32')
img_data = img_data/255 #normalization
print(img_data.shape)

num_classes = len(file_list)

# 카테고리 리스트로 선언
names = file_list

#라벨 이름 리턴
def getLabel(labels):
    labels = labels.tolist()
    return names[labels.index(1)]
def getLabel_Incoding(preds):
    index = np.argmax(preds)
    return names[index-1]    

# 훈련, 검증 데이터 셋 분리.

#원핫 인코딩 /  (파라미터 값, 0으로된 배열의 크기)
# 0: 1000000
# 1: 0100000
# 2: 0010000
#하나의 이미지에 대해 0과 1로 라벨링된(원핫인코딩된)배열을 리턴받음.
Y = np_utils.to_categorical(labels, num_classes)

#Shuffle the dataset
x,y = shuffle(img_data,Y, random_state=2)
# Split the dataset
# X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

#모델 생성 및 요약
# import creat_model as cm
def create_model():
    input_shape=(64,64,3)

    model = Sequential()
    model.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same',kernel_initializer='he_normal', activation = 'relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding='same',kernel_initializer='he_normal', activation = 'relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding='same',kernel_initializer='he_normal', activation = 'relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(16, (3, 3),padding='same',kernel_initializer='he_normal', activation = 'relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    
    model.add(Dense(256, kernel_initializer='he_normal', activation = 'relu'))
    model.add(Dense(128, kernel_initializer='he_normal', activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(7, activation = 'softmax'))

    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    
    return model
# model=Sequential([
#                   Conv2D(64,3,activation='relu',kernel_initializer='he_normal',input_shape=(64,64,3)),
#                   MaxPooling2D(3),
#                   Conv2D(128,3,activation='relu',kernel_initializer='he_normal'),
#                   Conv2D(256,3,activation='relu',kernel_initializer='he_normal'),
#                   MaxPooling2D(3),
#                   Flatten(),
#                   Dense(256,activation='relu'),
#                   Dense(7,activation='softmax',kernel_initializer='glorot_normal')
                  
# ])
model_custom = create_model()

model_custom.summary()

#Conduct k-Fold Cross-validation

from sklearn.model_selection import KFold

# kfold 교차 검증
# 데이터가 적은 데이터 셋에 대하여 정확도를 향상 시키기 위함.
# 이는 기존에 Training / Validation / Test 세개의 집단으로 분류하는것 보다 Training / Test로만 분류할때 학습 데이터 셋이 더 많기 때문.

# 5개의 폴드 세트로 분리하는 K Fold 객체와 폴드 세트별 정확도를 담을 리스트 객체 생성.
kf = KFold(n_splits=10, shuffle=False)

#Data Augmentation 기능 / 데이터 증강 기법
#모델의 성능을 높이면서 오버피팅을 극복하기 위해 학습 데이터의 다양성을 늘리기 위함.
#하나의 원본 이미지를 다양항 버전으로 만들어 학습시키는 것.
#대표적인 데이터 증강 기법으로는 원본 이미지를 수평 또는 수직 반전 시키는 방법, 회전시키는 방법, 일부를 자르는 방법,RGB채널 순서를 바꾸거나 
#픽셀값을 변경하여 원본 이미지의 색조를 변경시키는 것들이 있음.
#이러한 이미지 증강 기법을 tf.keras의 ImageDataGenerator 가 대신해줌.
#이 툴 이외에 Data Albumenation이나, ImgAug, Tensorflow Image Library 등 다양한 데이터 증강 기법 툴들이 있음.

from keras.preprocessing.image import ImageDataGenerator

# 이미지 증강법 1단계.ImageDataGenerator 객체(aug)를 생성하면서 증강을 수행할 유형들을 지정.
aug = ImageDataGenerator(
    rotation_range = 40,
    zoom_range = 0.2,
    horizontal_flip = True,
    fill_mode = 'nearest')

#Training Model 
BS = 8 # batch size
EPOCHS = 1000 # epochs

result = []
scores_loss = []
scores_acc = []
k_no = 0

#Kfold 객체의 split()을 호출하면 폴드별 학습용, 검증용 테스트의 로우 인덱스를 array로 반환
#split()이 알아서 학습용 검증용 데이터를 나누어줌. 위에서 k=5라고 지정한 경우 for문이 5번 돌아 가면서 학습용, 검증용 데이터를 나누어 줌.
for train_index, test_index in kf.split(x):
    #Kfold 객채의 split()으로 반환된 인덱스를 이용해 학습용, 검증용 테스트 데이터를 추출함.
    X_Train,X_Test = x[train_index], x[test_index]
    Y_Train,Y_Test = y[train_index], y[test_index]

    # 최적의 모델을 저장할 경로
    file_path = "./weights_best_emotion_detect4.h5"
    # 콜백 함수. (체크포인트, 조기 종료 선언)
    checkpoint = ModelCheckpoint(file_path, monitor='loss', save_best_only=True, mode='min')
    early = EarlyStopping(monitor="loss", mode="min", patience=8)

    callbacks_list = [checkpoint, early]

    #이미지 증강법 2단계 aug.flow(X,y,batch_size=,shuffle=) : X(훈련 이미지),y(라벨), 이미지를 한번에 몇개 업로드 시킬지에 대한 배치 사이즈,데이터 셔플 유무
    #flow 메소드로 생성한 객체는 Numpy Array Iterator 객체로 우리가 흔히 아는 Python Iterator처럼 loop문이나 next()함수를 사용해 Iterator 안에 데이터를 하나씩 호출 가능.

    hist = model_custom.fit_generator(aug.flow(X_Train, Y_Train), epochs=EPOCHS,validation_data=(X_Test, Y_Test), callbacks=callbacks_list)
    # model.fit(X_Train, Y_Train, batch_size=batch_size, epochs=epochs, validation_data=(X_Test, Y_Test), verbose=1)
    
#     model_custom.load_weights(file_path)
    result.append(model_custom.predict(X_Test))
    score = model_custom.evaluate(X_Test,Y_Test)
    scores_loss.append(score[0])
    scores_acc.append(score[1])
    k_no+=1

print(scores_acc,scores_loss)
# Out:
# file list: ['happy', 'contempt', 'fear', 'surprise', 'sadness', 'anger', 'disgust']
# Loaded the images of dataset-happy
#
# Loaded the images of dataset-contempt
#
# Loaded the images of dataset-fear
#
# Loaded the images of dataset-surprise
#
# Loaded the images of dataset-sadness
#
# Loaded the images of dataset-anger
#
# Loaded the images of dataset-disgust
#
# (981, 64, 64, 3)
# Model: "sequential_41"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_143 (Conv2D)         (None, 64, 64, 32)        896
#
#  max_pooling2d_138 (MaxPooli  (None, 32, 32, 32)       0
#  ng2D)
#
#  conv2d_144 (Conv2D)         (None, 32, 32, 64)        18496
#
#  max_pooling2d_139 (MaxPooli  (None, 16, 16, 64)       0
#  ng2D)
#
#  conv2d_145 (Conv2D)         (None, 16, 16, 64)        36928
#
#  max_pooling2d_140 (MaxPooli  (None, 8, 8, 64)         0
#  ng2D)
#
#  conv2d_146 (Conv2D)         (None, 8, 8, 32)          18464
#
#  max_pooling2d_141 (MaxPooli  (None, 4, 4, 32)         0
#  ng2D)
#
#  conv2d_147 (Conv2D)         (None, 4, 4, 32)          9248
#
#  max_pooling2d_142 (MaxPooli  (None, 2, 2, 32)         0
#  ng2D)
#
#  flatten_41 (Flatten)        (None, 128)               0
#
#  dense_88 (Dense)            (None, 256)               33024
#
#  dense_89 (Dense)            (None, 128)               32896
#
#  dropout_36 (Dropout)        (None, 128)               0
#
#  dense_90 (Dense)            (None, 7)                 903
#
# =================================================================
# Total params: 150,855
# Trainable params: 150,855
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# /var/folders/zh/v9f2b_v55ml9_yp9qr_69lk40000gn/T/ipykernel_7464/3279762783.py:213: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model_custom.fit_generator(aug.flow(X_Train, Y_Train), epochs=EPOCHS,validation_data=(X_Test, Y_Test), callbacks=callbacks_list)
# 2022-11-20 02:26:40.088842: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 26/28 [==========================>...] - ETA: 0s - loss: 1.9380 - accuracy: 0.2103
# 2022-11-20 02:26:41.741474: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 28/28 [==============================] - 2s 47ms/step - loss: 1.9309 - accuracy: 0.2109 - val_loss: 1.8958 - val_accuracy: 0.1919
# Epoch 2/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 1.8541 - accuracy: 0.2540 - val_loss: 1.8667 - val_accuracy: 0.1919
# Epoch 3/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 1.8628 - accuracy: 0.2302 - val_loss: 1.8789 - val_accuracy: 0.2020
# Epoch 4/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 1.8470 - accuracy: 0.2268 - val_loss: 1.8785 - val_accuracy: 0.1818
# Epoch 5/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 1.7689 - accuracy: 0.3107 - val_loss: 1.7298 - val_accuracy: 0.3131
# Epoch 6/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 1.7029 - accuracy: 0.3549 - val_loss: 1.5990 - val_accuracy: 0.3434
# Epoch 7/1000
# 28/28 [==============================] - 1s 24ms/step - loss: 1.5837 - accuracy: 0.4014 - val_loss: 1.5407 - val_accuracy: 0.4444
# Epoch 8/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 1.5044 - accuracy: 0.4478 - val_loss: 1.3896 - val_accuracy: 0.4848
# Epoch 9/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 1.4219 - accuracy: 0.4728 - val_loss: 1.3270 - val_accuracy: 0.5051
# Epoch 10/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 1.3492 - accuracy: 0.4887 - val_loss: 1.2757 - val_accuracy: 0.4848
# Epoch 11/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2715 - accuracy: 0.4943 - val_loss: 1.4285 - val_accuracy: 0.3939
# Epoch 12/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2877 - accuracy: 0.5000 - val_loss: 1.3303 - val_accuracy: 0.4444
# Epoch 13/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2624 - accuracy: 0.5045 - val_loss: 1.1452 - val_accuracy: 0.5556
# Epoch 14/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 1.2003 - accuracy: 0.5215 - val_loss: 1.2027 - val_accuracy: 0.5051
# Epoch 15/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1939 - accuracy: 0.5454 - val_loss: 1.1699 - val_accuracy: 0.4646
# Epoch 16/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1124 - accuracy: 0.5828 - val_loss: 1.0838 - val_accuracy: 0.5758
# Epoch 17/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1581 - accuracy: 0.5261 - val_loss: 1.2135 - val_accuracy: 0.5051
# Epoch 18/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1130 - accuracy: 0.5533 - val_loss: 1.0710 - val_accuracy: 0.5556
# Epoch 19/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1010 - accuracy: 0.5669 - val_loss: 1.1614 - val_accuracy: 0.4747
# Epoch 20/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 1.0837 - accuracy: 0.5567 - val_loss: 1.2546 - val_accuracy: 0.5152
# Epoch 21/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 1.0625 - accuracy: 0.5828 - val_loss: 1.1014 - val_accuracy: 0.5758
# Epoch 22/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 1.0735 - accuracy: 0.5805 - val_loss: 1.0948 - val_accuracy: 0.6162
# Epoch 23/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 1.0430 - accuracy: 0.5816 - val_loss: 1.0365 - val_accuracy: 0.5556
# Epoch 24/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 1.0011 - accuracy: 0.6077 - val_loss: 1.0446 - val_accuracy: 0.5758
# Epoch 25/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 1.0252 - accuracy: 0.5805 - val_loss: 1.0651 - val_accuracy: 0.6061
# Epoch 26/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9815 - accuracy: 0.6066 - val_loss: 0.9467 - val_accuracy: 0.6465
# Epoch 27/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.9834 - accuracy: 0.6054 - val_loss: 0.9666 - val_accuracy: 0.5859
# Epoch 28/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9537 - accuracy: 0.6349 - val_loss: 0.9704 - val_accuracy: 0.6162
# Epoch 29/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 1.0023 - accuracy: 0.5998 - val_loss: 0.9727 - val_accuracy: 0.6162
# Epoch 30/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.9356 - accuracy: 0.6145 - val_loss: 1.1015 - val_accuracy: 0.5859
# Epoch 31/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9781 - accuracy: 0.6179 - val_loss: 1.0108 - val_accuracy: 0.6465
# Epoch 32/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9544 - accuracy: 0.6224 - val_loss: 0.9937 - val_accuracy: 0.6162
# Epoch 33/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9796 - accuracy: 0.5998 - val_loss: 1.0264 - val_accuracy: 0.6061
# Epoch 34/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.9411 - accuracy: 0.6066 - val_loss: 1.0791 - val_accuracy: 0.6061
# Epoch 35/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.9282 - accuracy: 0.6270 - val_loss: 0.9099 - val_accuracy: 0.6364
# Epoch 36/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9258 - accuracy: 0.6406 - val_loss: 0.9508 - val_accuracy: 0.6061
# Epoch 37/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.9050 - accuracy: 0.6315 - val_loss: 1.2317 - val_accuracy: 0.5758
# Epoch 38/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.9025 - accuracy: 0.6542 - val_loss: 0.9845 - val_accuracy: 0.6061
# Epoch 39/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8789 - accuracy: 0.6338 - val_loss: 1.0128 - val_accuracy: 0.6162
# Epoch 40/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8734 - accuracy: 0.6531 - val_loss: 0.9377 - val_accuracy: 0.6061
# Epoch 41/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.9055 - accuracy: 0.6100 - val_loss: 0.8685 - val_accuracy: 0.6263
# Epoch 42/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.9111 - accuracy: 0.6247 - val_loss: 0.8897 - val_accuracy: 0.6364
# Epoch 43/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8330 - accuracy: 0.6621 - val_loss: 0.9079 - val_accuracy: 0.6465
# Epoch 44/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8450 - accuracy: 0.6372 - val_loss: 1.1140 - val_accuracy: 0.5556
# Epoch 45/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8429 - accuracy: 0.6519 - val_loss: 0.9788 - val_accuracy: 0.6263
# Epoch 46/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8381 - accuracy: 0.6587 - val_loss: 0.9446 - val_accuracy: 0.6162
# Epoch 47/1000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.8253 - accuracy: 0.6610 - val_loss: 0.8791 - val_accuracy: 0.6566
# Epoch 48/1000
# 28/28 [==============================] - 1s 24ms/step - loss: 0.8121 - accuracy: 0.6723 - val_loss: 0.8578 - val_accuracy: 0.6364
# Epoch 49/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8610 - accuracy: 0.6553 - val_loss: 0.8210 - val_accuracy: 0.6667
# Epoch 50/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.8160 - accuracy: 0.6610 - val_loss: 1.0942 - val_accuracy: 0.5758
# Epoch 51/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8323 - accuracy: 0.6565 - val_loss: 0.9304 - val_accuracy: 0.6061
# Epoch 52/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8039 - accuracy: 0.6905 - val_loss: 0.8155 - val_accuracy: 0.6768
# Epoch 53/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.8182 - accuracy: 0.6689 - val_loss: 0.8217 - val_accuracy: 0.6667
# Epoch 54/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7708 - accuracy: 0.6825 - val_loss: 0.8438 - val_accuracy: 0.6465
# Epoch 55/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.8342 - accuracy: 0.6406 - val_loss: 0.8537 - val_accuracy: 0.6263
# Epoch 56/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7978 - accuracy: 0.6769 - val_loss: 0.8104 - val_accuracy: 0.7071
# Epoch 57/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7761 - accuracy: 0.6780 - val_loss: 0.9553 - val_accuracy: 0.6465
# Epoch 58/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7811 - accuracy: 0.6757 - val_loss: 0.8560 - val_accuracy: 0.6566
# Epoch 59/1000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.7861 - accuracy: 0.6757 - val_loss: 0.9881 - val_accuracy: 0.6263
# Epoch 60/1000
# 28/28 [==============================] - 1s 32ms/step - loss: 0.7821 - accuracy: 0.6905 - val_loss: 0.8743 - val_accuracy: 0.6768
# Epoch 61/1000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.7733 - accuracy: 0.6791 - val_loss: 0.8724 - val_accuracy: 0.6869
# Epoch 62/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7828 - accuracy: 0.6757 - val_loss: 0.7631 - val_accuracy: 0.6869
# 4/4 [==============================] - 0s 31ms/step
# 2022-11-20 02:27:17.782386: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8438 - accuracy: 0.6465
# Epoch 1/1000
# 28/28 [==============================] - 1s 31ms/step - loss: 0.7818 - accuracy: 0.6636 - val_loss: 0.7181 - val_accuracy: 0.6837
# Epoch 2/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8433 - accuracy: 0.6716 - val_loss: 0.6905 - val_accuracy: 0.6633
# Epoch 3/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8129 - accuracy: 0.6897 - val_loss: 0.6789 - val_accuracy: 0.6939
# Epoch 4/1000
# 28/28 [==============================] - 1s 22ms/step - loss: 0.7627 - accuracy: 0.6886 - val_loss: 0.6831 - val_accuracy: 0.6939
# Epoch 5/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8273 - accuracy: 0.6704 - val_loss: 0.8437 - val_accuracy: 0.6633
# Epoch 6/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7993 - accuracy: 0.6818 - val_loss: 0.6804 - val_accuracy: 0.7041
# Epoch 7/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7841 - accuracy: 0.6852 - val_loss: 0.7025 - val_accuracy: 0.7143
# Epoch 8/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8063 - accuracy: 0.6829 - val_loss: 0.6969 - val_accuracy: 0.7041
# Epoch 9/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7879 - accuracy: 0.6852 - val_loss: 0.6927 - val_accuracy: 0.7449
# Epoch 10/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7666 - accuracy: 0.6931 - val_loss: 0.6879 - val_accuracy: 0.7041
# Epoch 11/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7866 - accuracy: 0.6852 - val_loss: 0.6564 - val_accuracy: 0.6939
# Epoch 12/1000
# 28/28 [==============================] - 1s 22ms/step - loss: 0.7986 - accuracy: 0.6829 - val_loss: 0.6429 - val_accuracy: 0.7245
# 4/4 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6831 - accuracy: 0.6939
# Epoch 1/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7752 - accuracy: 0.6795 - val_loss: 0.6829 - val_accuracy: 0.6837
# Epoch 2/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.8586 - accuracy: 0.6433 - val_loss: 0.7866 - val_accuracy: 0.6735
# Epoch 3/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7912 - accuracy: 0.6750 - val_loss: 0.7058 - val_accuracy: 0.7551
# Epoch 4/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8121 - accuracy: 0.6501 - val_loss: 0.8032 - val_accuracy: 0.6327
# Epoch 5/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7849 - accuracy: 0.6806 - val_loss: 0.7280 - val_accuracy: 0.6837
# Epoch 6/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7797 - accuracy: 0.6625 - val_loss: 0.7209 - val_accuracy: 0.7143
# Epoch 7/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8138 - accuracy: 0.6682 - val_loss: 0.7270 - val_accuracy: 0.7041
# Epoch 8/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7792 - accuracy: 0.6795 - val_loss: 0.7580 - val_accuracy: 0.6837
# Epoch 9/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7270 - accuracy: 0.7022 - val_loss: 0.7310 - val_accuracy: 0.6939
# Epoch 10/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7509 - accuracy: 0.6818 - val_loss: 0.7183 - val_accuracy: 0.6837
# Epoch 11/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7568 - accuracy: 0.6897 - val_loss: 0.7838 - val_accuracy: 0.6122
# Epoch 12/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7460 - accuracy: 0.6874 - val_loss: 0.8198 - val_accuracy: 0.6327
# Epoch 13/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7354 - accuracy: 0.6920 - val_loss: 0.7777 - val_accuracy: 0.6837
# Epoch 14/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7704 - accuracy: 0.6772 - val_loss: 0.8300 - val_accuracy: 0.6939
# Epoch 15/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7530 - accuracy: 0.6886 - val_loss: 0.7171 - val_accuracy: 0.7041
# Epoch 16/1000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.7259 - accuracy: 0.6954 - val_loss: 0.7645 - val_accuracy: 0.6735
# Epoch 17/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.7477 - accuracy: 0.6750 - val_loss: 0.7997 - val_accuracy: 0.6327
# Epoch 18/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.7132 - accuracy: 0.7101 - val_loss: 0.7436 - val_accuracy: 0.6735
# Epoch 19/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7592 - accuracy: 0.6863 - val_loss: 0.8287 - val_accuracy: 0.6735
# Epoch 20/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7539 - accuracy: 0.6863 - val_loss: 0.8058 - val_accuracy: 0.6327
# Epoch 21/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7374 - accuracy: 0.6750 - val_loss: 0.8288 - val_accuracy: 0.6327
# Epoch 22/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7192 - accuracy: 0.7022 - val_loss: 0.7021 - val_accuracy: 0.7347
# Epoch 23/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6862 - accuracy: 0.7191 - val_loss: 0.8590 - val_accuracy: 0.6224
# Epoch 24/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7357 - accuracy: 0.6784 - val_loss: 0.7306 - val_accuracy: 0.7245
# Epoch 25/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7085 - accuracy: 0.7135 - val_loss: 0.7629 - val_accuracy: 0.6939
# Epoch 26/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7246 - accuracy: 0.6965 - val_loss: 0.7130 - val_accuracy: 0.6939
# Epoch 27/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6909 - accuracy: 0.7248 - val_loss: 0.8004 - val_accuracy: 0.6837
# Epoch 28/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7089 - accuracy: 0.6920 - val_loss: 0.7610 - val_accuracy: 0.6633
# Epoch 29/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7210 - accuracy: 0.6840 - val_loss: 0.8036 - val_accuracy: 0.7041
# Epoch 30/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7301 - accuracy: 0.6920 - val_loss: 0.8103 - val_accuracy: 0.6735
# Epoch 31/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7159 - accuracy: 0.7237 - val_loss: 0.7796 - val_accuracy: 0.6429
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8590 - accuracy: 0.6224
# Epoch 1/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6959 - accuracy: 0.7101 - val_loss: 0.7015 - val_accuracy: 0.6735
# Epoch 2/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7072 - accuracy: 0.7055 - val_loss: 0.7112 - val_accuracy: 0.7041
# Epoch 3/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7424 - accuracy: 0.6750 - val_loss: 0.6718 - val_accuracy: 0.7551
# Epoch 4/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7138 - accuracy: 0.7169 - val_loss: 0.7085 - val_accuracy: 0.6837
# Epoch 5/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7213 - accuracy: 0.7044 - val_loss: 0.7316 - val_accuracy: 0.6531
# Epoch 6/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7103 - accuracy: 0.7055 - val_loss: 0.7060 - val_accuracy: 0.7041
# Epoch 7/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.7061 - accuracy: 0.7033 - val_loss: 0.6922 - val_accuracy: 0.6837
# Epoch 8/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7286 - accuracy: 0.6999 - val_loss: 0.7271 - val_accuracy: 0.6837
# Epoch 9/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7082 - accuracy: 0.7112 - val_loss: 0.7262 - val_accuracy: 0.6429
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7015 - accuracy: 0.6735
# Epoch 1/1000
# 28/28 [==============================] - 1s 22ms/step - loss: 0.7335 - accuracy: 0.6908 - val_loss: 0.5629 - val_accuracy: 0.7653
# Epoch 2/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7472 - accuracy: 0.6954 - val_loss: 0.5583 - val_accuracy: 0.7449
# Epoch 3/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6854 - accuracy: 0.7282 - val_loss: 0.5969 - val_accuracy: 0.6939
# Epoch 4/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7285 - accuracy: 0.7157 - val_loss: 0.6318 - val_accuracy: 0.7245
# Epoch 5/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7335 - accuracy: 0.7123 - val_loss: 0.6801 - val_accuracy: 0.7245
# Epoch 6/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7367 - accuracy: 0.6840 - val_loss: 0.6336 - val_accuracy: 0.7041
# Epoch 7/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6861 - accuracy: 0.7112 - val_loss: 0.5748 - val_accuracy: 0.7449
# Epoch 8/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7317 - accuracy: 0.6965 - val_loss: 0.5430 - val_accuracy: 0.7959
# Epoch 9/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7303 - accuracy: 0.6999 - val_loss: 0.6276 - val_accuracy: 0.7041
# Epoch 10/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6888 - accuracy: 0.7157 - val_loss: 0.5557 - val_accuracy: 0.7347
# Epoch 11/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.7226 - accuracy: 0.7010 - val_loss: 0.6360 - val_accuracy: 0.6939
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5969 - accuracy: 0.6939
# Epoch 1/1000
# 28/28 [==============================] - 1s 22ms/step - loss: 0.7268 - accuracy: 0.6874 - val_loss: 0.5699 - val_accuracy: 0.7653
# Epoch 2/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7027 - accuracy: 0.7010 - val_loss: 0.6358 - val_accuracy: 0.7755
# Epoch 3/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7596 - accuracy: 0.6727 - val_loss: 0.6647 - val_accuracy: 0.7347
# Epoch 4/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7094 - accuracy: 0.7067 - val_loss: 0.6201 - val_accuracy: 0.8469
# Epoch 5/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7157 - accuracy: 0.6976 - val_loss: 0.6477 - val_accuracy: 0.8163
# Epoch 6/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6785 - accuracy: 0.7033 - val_loss: 0.6510 - val_accuracy: 0.7755
# Epoch 7/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7274 - accuracy: 0.6818 - val_loss: 0.6918 - val_accuracy: 0.7449
# Epoch 8/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.7081 - accuracy: 0.6976 - val_loss: 0.6415 - val_accuracy: 0.7551
# Epoch 9/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7293 - accuracy: 0.6693 - val_loss: 0.6616 - val_accuracy: 0.7653
# Epoch 10/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6909 - accuracy: 0.7010 - val_loss: 0.6510 - val_accuracy: 0.7551
# Epoch 11/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7268 - accuracy: 0.6988 - val_loss: 0.7000 - val_accuracy: 0.7143
# Epoch 12/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7195 - accuracy: 0.7078 - val_loss: 0.6730 - val_accuracy: 0.7959
# Epoch 13/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6777 - accuracy: 0.7022 - val_loss: 0.6660 - val_accuracy: 0.7755
# Epoch 14/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6812 - accuracy: 0.7225 - val_loss: 0.6918 - val_accuracy: 0.7959
# Epoch 15/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6889 - accuracy: 0.6897 - val_loss: 0.6710 - val_accuracy: 0.7755
# Epoch 16/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6998 - accuracy: 0.6999 - val_loss: 0.6654 - val_accuracy: 0.7857
# Epoch 17/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6786 - accuracy: 0.7044 - val_loss: 0.7108 - val_accuracy: 0.7449
# Epoch 18/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6607 - accuracy: 0.7157 - val_loss: 0.6342 - val_accuracy: 0.8163
# Epoch 19/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6535 - accuracy: 0.7180 - val_loss: 0.6664 - val_accuracy: 0.8061
# Epoch 20/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6754 - accuracy: 0.6920 - val_loss: 0.6483 - val_accuracy: 0.7959
# Epoch 21/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6476 - accuracy: 0.7157 - val_loss: 0.6965 - val_accuracy: 0.7755
# Epoch 22/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6410 - accuracy: 0.7225 - val_loss: 0.6601 - val_accuracy: 0.7857
# Epoch 23/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6621 - accuracy: 0.7180 - val_loss: 0.6941 - val_accuracy: 0.7653
# Epoch 24/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6707 - accuracy: 0.7146 - val_loss: 0.6310 - val_accuracy: 0.8265
# Epoch 25/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6441 - accuracy: 0.7293 - val_loss: 0.6527 - val_accuracy: 0.7755
# Epoch 26/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6618 - accuracy: 0.7067 - val_loss: 0.7061 - val_accuracy: 0.7959
# Epoch 27/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6906 - accuracy: 0.7022 - val_loss: 0.6570 - val_accuracy: 0.7959
# Epoch 28/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6383 - accuracy: 0.7169 - val_loss: 0.6921 - val_accuracy: 0.7653
# Epoch 29/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6397 - accuracy: 0.7282 - val_loss: 0.7125 - val_accuracy: 0.7755
# Epoch 30/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6831 - accuracy: 0.7022 - val_loss: 0.7790 - val_accuracy: 0.7245
# Epoch 31/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6931 - accuracy: 0.6908 - val_loss: 0.6368 - val_accuracy: 0.7959
# Epoch 32/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6548 - accuracy: 0.7282 - val_loss: 0.7177 - val_accuracy: 0.7755
# Epoch 33/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6302 - accuracy: 0.7146 - val_loss: 0.6569 - val_accuracy: 0.7551
# Epoch 34/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6375 - accuracy: 0.7282 - val_loss: 0.6822 - val_accuracy: 0.7857
# Epoch 35/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6588 - accuracy: 0.7180 - val_loss: 0.6645 - val_accuracy: 0.7857
# Epoch 36/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6439 - accuracy: 0.7327 - val_loss: 0.6623 - val_accuracy: 0.7857
# Epoch 37/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6347 - accuracy: 0.7452 - val_loss: 0.6952 - val_accuracy: 0.7755
# Epoch 38/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6219 - accuracy: 0.7508 - val_loss: 0.6924 - val_accuracy: 0.7653
# Epoch 39/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6519 - accuracy: 0.7282 - val_loss: 0.6151 - val_accuracy: 0.7959
# Epoch 40/1000
# 28/28 [==============================] - 1s 22ms/step - loss: 0.6114 - accuracy: 0.7316 - val_loss: 0.7047 - val_accuracy: 0.7551
# Epoch 41/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6145 - accuracy: 0.7214 - val_loss: 0.6146 - val_accuracy: 0.8061
# Epoch 42/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6401 - accuracy: 0.7361 - val_loss: 0.6942 - val_accuracy: 0.7857
# Epoch 43/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6301 - accuracy: 0.7452 - val_loss: 0.7255 - val_accuracy: 0.7857
# Epoch 44/1000
# 28/28 [==============================] - 1s 22ms/step - loss: 0.6348 - accuracy: 0.7373 - val_loss: 0.6595 - val_accuracy: 0.7755
# Epoch 45/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6256 - accuracy: 0.7169 - val_loss: 0.6661 - val_accuracy: 0.7755
# Epoch 46/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6565 - accuracy: 0.7339 - val_loss: 0.6916 - val_accuracy: 0.7857
# Epoch 47/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6357 - accuracy: 0.7237 - val_loss: 0.6540 - val_accuracy: 0.7755
# Epoch 48/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.5942 - accuracy: 0.7282 - val_loss: 0.6603 - val_accuracy: 0.7857
# Epoch 49/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6073 - accuracy: 0.7327 - val_loss: 0.6645 - val_accuracy: 0.7857
# Epoch 50/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.5904 - accuracy: 0.7508 - val_loss: 0.9322 - val_accuracy: 0.7245
# Epoch 51/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6330 - accuracy: 0.7237 - val_loss: 0.7214 - val_accuracy: 0.6939
# Epoch 52/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5916 - accuracy: 0.7407 - val_loss: 0.6984 - val_accuracy: 0.7857
# Epoch 53/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5973 - accuracy: 0.7418 - val_loss: 0.6730 - val_accuracy: 0.7959
# Epoch 54/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5936 - accuracy: 0.7395 - val_loss: 0.6822 - val_accuracy: 0.7959
# Epoch 55/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5993 - accuracy: 0.7305 - val_loss: 0.6699 - val_accuracy: 0.7959
# Epoch 56/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6443 - accuracy: 0.7225 - val_loss: 0.6926 - val_accuracy: 0.7857
# Epoch 57/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6257 - accuracy: 0.7395 - val_loss: 0.6983 - val_accuracy: 0.7755
# Epoch 58/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5951 - accuracy: 0.7701 - val_loss: 0.7038 - val_accuracy: 0.7857
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9322 - accuracy: 0.7245
# Epoch 1/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6763 - accuracy: 0.7248 - val_loss: 0.4169 - val_accuracy: 0.8265
# Epoch 2/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6711 - accuracy: 0.7237 - val_loss: 0.4282 - val_accuracy: 0.8265
# Epoch 3/1000
# 28/28 [==============================] - 1s 22ms/step - loss: 0.6317 - accuracy: 0.7497 - val_loss: 0.4936 - val_accuracy: 0.7755
# Epoch 4/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6266 - accuracy: 0.7475 - val_loss: 0.4802 - val_accuracy: 0.7959
# Epoch 5/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6212 - accuracy: 0.7441 - val_loss: 0.4709 - val_accuracy: 0.8265
# Epoch 6/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6445 - accuracy: 0.7214 - val_loss: 0.4212 - val_accuracy: 0.8367
# Epoch 7/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6082 - accuracy: 0.7407 - val_loss: 0.4561 - val_accuracy: 0.8367
# Epoch 8/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6348 - accuracy: 0.7441 - val_loss: 0.4331 - val_accuracy: 0.8163
# Epoch 9/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.5837 - accuracy: 0.7486 - val_loss: 0.4329 - val_accuracy: 0.7857
# Epoch 10/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5864 - accuracy: 0.7542 - val_loss: 0.4411 - val_accuracy: 0.8163
# Epoch 11/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6169 - accuracy: 0.7497 - val_loss: 0.4761 - val_accuracy: 0.8163
# Epoch 12/1000
# 28/28 [==============================] - 1s 23ms/step - loss: 0.5834 - accuracy: 0.7656 - val_loss: 0.4435 - val_accuracy: 0.7959
# Epoch 13/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5907 - accuracy: 0.7339 - val_loss: 0.4669 - val_accuracy: 0.7551
# Epoch 14/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6257 - accuracy: 0.7418 - val_loss: 0.4281 - val_accuracy: 0.8163
# Epoch 15/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5863 - accuracy: 0.7690 - val_loss: 0.5333 - val_accuracy: 0.7755
# Epoch 16/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6410 - accuracy: 0.7293 - val_loss: 0.4673 - val_accuracy: 0.7959
# Epoch 17/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5993 - accuracy: 0.7554 - val_loss: 0.4693 - val_accuracy: 0.7959
# Epoch 18/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6267 - accuracy: 0.7384 - val_loss: 0.4390 - val_accuracy: 0.7755
# Epoch 19/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5966 - accuracy: 0.7463 - val_loss: 0.4583 - val_accuracy: 0.7959
# Epoch 20/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6209 - accuracy: 0.7339 - val_loss: 0.4616 - val_accuracy: 0.8061
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4435 - accuracy: 0.7959
# Epoch 1/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.5659 - accuracy: 0.7565 - val_loss: 0.5317 - val_accuracy: 0.7347
# Epoch 2/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6112 - accuracy: 0.7531 - val_loss: 0.5768 - val_accuracy: 0.7041
# Epoch 3/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5783 - accuracy: 0.7610 - val_loss: 0.5065 - val_accuracy: 0.7551
# Epoch 4/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6142 - accuracy: 0.7418 - val_loss: 0.5896 - val_accuracy: 0.7245
# Epoch 5/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5950 - accuracy: 0.7452 - val_loss: 0.5294 - val_accuracy: 0.7143
# Epoch 6/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5671 - accuracy: 0.7497 - val_loss: 0.6555 - val_accuracy: 0.7347
# Epoch 7/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.5609 - accuracy: 0.7588 - val_loss: 0.6071 - val_accuracy: 0.7245
# Epoch 8/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.5593 - accuracy: 0.7565 - val_loss: 0.5299 - val_accuracy: 0.7653
# Epoch 9/1000
# 28/28 [==============================] - 1s 22ms/step - loss: 0.5511 - accuracy: 0.7463 - val_loss: 0.5676 - val_accuracy: 0.7245
# Epoch 10/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5899 - accuracy: 0.7678 - val_loss: 0.5572 - val_accuracy: 0.7551
# Epoch 11/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5887 - accuracy: 0.7508 - val_loss: 0.5608 - val_accuracy: 0.6429
# Epoch 12/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5713 - accuracy: 0.7542 - val_loss: 0.7327 - val_accuracy: 0.7041
# Epoch 13/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5928 - accuracy: 0.7656 - val_loss: 0.6504 - val_accuracy: 0.6939
# Epoch 14/1000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.5254 - accuracy: 0.7769 - val_loss: 0.6334 - val_accuracy: 0.6735
# Epoch 15/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.5912 - accuracy: 0.7599 - val_loss: 0.6750 - val_accuracy: 0.6837
# Epoch 16/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5351 - accuracy: 0.7803 - val_loss: 0.5907 - val_accuracy: 0.7143
# Epoch 17/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5974 - accuracy: 0.7452 - val_loss: 0.6679 - val_accuracy: 0.6735
# Epoch 18/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5971 - accuracy: 0.7667 - val_loss: 0.6244 - val_accuracy: 0.7449
# Epoch 19/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5231 - accuracy: 0.7882 - val_loss: 0.5370 - val_accuracy: 0.7245
# Epoch 20/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.5755 - accuracy: 0.7542 - val_loss: 0.6435 - val_accuracy: 0.7245
# Epoch 21/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5642 - accuracy: 0.7576 - val_loss: 0.5788 - val_accuracy: 0.7143
# Epoch 22/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.5794 - accuracy: 0.7497 - val_loss: 0.6656 - val_accuracy: 0.6429
# Epoch 23/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5653 - accuracy: 0.7565 - val_loss: 0.6206 - val_accuracy: 0.7143
# Epoch 24/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.5614 - accuracy: 0.7656 - val_loss: 0.5543 - val_accuracy: 0.7449
# Epoch 25/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5521 - accuracy: 0.7746 - val_loss: 0.6583 - val_accuracy: 0.7041
# Epoch 26/1000
# 28/28 [==============================] - 1s 23ms/step - loss: 0.5291 - accuracy: 0.7667 - val_loss: 0.6611 - val_accuracy: 0.7143
# Epoch 27/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5301 - accuracy: 0.7792 - val_loss: 0.6217 - val_accuracy: 0.6735
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5370 - accuracy: 0.7245
# Epoch 1/1000
# 28/28 [==============================] - 1s 23ms/step - loss: 0.5733 - accuracy: 0.7407 - val_loss: 0.4424 - val_accuracy: 0.8265
# Epoch 2/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5768 - accuracy: 0.7531 - val_loss: 0.5292 - val_accuracy: 0.7551
# Epoch 3/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5312 - accuracy: 0.7780 - val_loss: 0.4184 - val_accuracy: 0.8367
# Epoch 4/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5873 - accuracy: 0.7554 - val_loss: 0.4707 - val_accuracy: 0.8265
# Epoch 5/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5524 - accuracy: 0.7565 - val_loss: 0.4643 - val_accuracy: 0.8163
# Epoch 6/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5616 - accuracy: 0.7565 - val_loss: 0.4722 - val_accuracy: 0.7653
# Epoch 7/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.5832 - accuracy: 0.7429 - val_loss: 0.5404 - val_accuracy: 0.7857
# Epoch 8/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6090 - accuracy: 0.7361 - val_loss: 0.5838 - val_accuracy: 0.7245
# Epoch 9/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5832 - accuracy: 0.7475 - val_loss: 0.5421 - val_accuracy: 0.7449
# Epoch 10/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.5589 - accuracy: 0.7588 - val_loss: 0.5172 - val_accuracy: 0.7857
# Epoch 11/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5410 - accuracy: 0.7701 - val_loss: 0.5487 - val_accuracy: 0.7143
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4184 - accuracy: 0.8367
# Epoch 1/1000
# 28/28 [==============================] - 1s 21ms/step - loss: 0.5546 - accuracy: 0.7769 - val_loss: 0.3823 - val_accuracy: 0.8776
# Epoch 2/1000
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5332 - accuracy: 0.7724 - val_loss: 0.3900 - val_accuracy: 0.8673
# Epoch 3/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5603 - accuracy: 0.7746 - val_loss: 0.3692 - val_accuracy: 0.8571
# Epoch 4/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5605 - accuracy: 0.7644 - val_loss: 0.3922 - val_accuracy: 0.8776
# Epoch 5/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.5883 - accuracy: 0.7542 - val_loss: 0.3500 - val_accuracy: 0.9082
# Epoch 6/1000
# 28/28 [==============================] - 1s 18ms/step - loss: 0.5734 - accuracy: 0.7486 - val_loss: 0.3977 - val_accuracy: 0.8367
# Epoch 7/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5593 - accuracy: 0.7531 - val_loss: 0.3708 - val_accuracy: 0.8673
# Epoch 8/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5397 - accuracy: 0.7622 - val_loss: 0.4442 - val_accuracy: 0.8571
# Epoch 9/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5910 - accuracy: 0.7486 - val_loss: 0.4185 - val_accuracy: 0.8776
# Epoch 10/1000
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6018 - accuracy: 0.7486 - val_loss: 0.4107 - val_accuracy: 0.8673
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3900 - accuracy: 0.8673
# [0.6464646458625793, 0.6938775181770325, 0.6224489808082581, 0.6734693646430969, 0.6938775181770325, 0.7244898080825806, 0.795918345451355, 0.7244898080825806, 0.8367346525192261, 0.8673469424247742] [0.8438491821289062, 0.6830649971961975, 0.8589544892311096, 0.7015393376350403, 0.5969315767288208, 0.9322327971458435, 0.4435230791568756, 0.5369560122489929, 0.4184301197528839, 0.39000803232192993]

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train','val'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model_custom.evaluate(X_Test,Y_Test)
# Out:
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3385 - accuracy: 0.8265
# [0.33854910731315613, 0.8265305757522583]

# %%
preds= model_custom.predict(X_Test[2:3])
preds
# Out:
# 1/1 [==============================] - 0s 137ms/step
# array([[4.9822551e-12, 2.7136064e-06, 8.3030164e-01, 1.3563353e-02,
#         1.5613228e-01, 3.1170968e-09, 8.9134655e-12]], dtype=float32)

# %%
plt.bar(range(1,8), preds[0])
plt.xlabel('class')
plt.ylabel('prob.')
plt.show()

# %%
getLabel_Incoding(preds)
# Out:
# 'contempt'

# %%
plt.imshow(X_Test[2].reshape(48,48,3))

# %%
plt.imshow(x[1])

# %%
y[1]
# Out:
# array([0., 0., 1., 0., 0., 0., 0.], dtype=float32)

# %%
print(getLabel(y[1]))
# Out:
# contempt

# %%
Y[0]
# Out:
# array([1., 0., 0., 0., 0., 0., 0.], dtype=float32)

# %%
from keras.models import load_model
emotion_detect_model = load_model('weights_best_emotion_detect3.h5')

# %%
emotion_detect_model.summary()
# Out:
# Model: "sequential_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_117 (Conv2D)         (None, 64, 64, 16)        208
#
#  max_pooling2d_112 (MaxPooli  (None, 32, 32, 16)       0
#  ng2D)
#
#  conv2d_118 (Conv2D)         (None, 32, 32, 32)        2080
#
#  max_pooling2d_113 (MaxPooli  (None, 16, 16, 32)       0
#  ng2D)
#
#  conv2d_119 (Conv2D)         (None, 16, 16, 32)        4128
#
#  max_pooling2d_114 (MaxPooli  (None, 8, 8, 32)         0
#  ng2D)
#
#  conv2d_120 (Conv2D)         (None, 8, 8, 64)          8256
#
#  max_pooling2d_115 (MaxPooli  (None, 4, 4, 64)         0
#  ng2D)
#
#  conv2d_121 (Conv2D)         (None, 4, 4, 128)         32896
#
#  max_pooling2d_116 (MaxPooli  (None, 2, 2, 128)        0
#  ng2D)
#
#  flatten_36 (Flatten)        (None, 512)               0
#
#  dense_73 (Dense)            (None, 256)               131328
#
#  dense_74 (Dense)            (None, 128)               32896
#
#  dropout_31 (Dropout)        (None, 128)               0
#
#  dense_75 (Dense)            (None, 7)                 903
#
# =================================================================
# Total params: 212,695
# Trainable params: 212,695
# Non-trainable params: 0
# _________________________________________________________________

# %%
img = cv2.imread('./image/croped_image19.jpg')
preds= emotion_detect_model.predict(img.reshape(-1,64,64,3))
text = getLabel_Incoding(preds)
print(text)
# preds= emotion_detect_model.predict()
# Out:
# 1/1 [==============================] - 0s 135ms/step
# contempt
# 2022-11-20 02:06:16.970052: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
print(getLabel(y[2]))
# Out:
# fear

# %%
#happy
# crop = img[10:290,10:290]
#sadness
# crop = img[660:940,1630:1910]
#anger
# crop = img[1000:1280,1630:1910]
#surprise
# crop = img[10:290,1630:1910]
#disgust
# crop = img[320:600,10:290]
#contempt
# crop = img[320:600,345:625]

#fear
crop = img[1000:1280,10:290]

a = 'fear'
dst = cv2.resize(crop, (300, 300), interpolation=cv2.INTER_LINEAR) 
cv2.imwrite(f'./emoticon/{a}.jpg', dst)
# Out:
# True

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os,cv2
import glob as gb
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#matplotlib을 통해 보여줄 그래프의 크기를 직접 지정해 준것.
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import tensorflow as tf

from keras.utils import np_utils
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
from keras.models import Sequential
from keras.layers import *
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.optimizers import *
from keras.layers import BatchNormalization
from keras.optimizers import Adam , RMSprop
from keras.callbacks import EarlyStopping ,ReduceLROnPlateau ,ModelCheckpoint

import os
data_path = './Input/CK+48'
file_list = os.listdir(data_path)
file_list.remove('.DS_Store')
print("file list:",file_list)

# Any results you write to the current directory are saved as output

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.datasets import make_classification
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau


#디렉토리에서 이미지를 추출하기

data_dir_list = os.listdir(data_path)

num_epoch=10

img_data_list=[]


#우리가 파일을 만든 순서가 아닌 컴퓨터가 지가 읽는 순서대로 파일을 불러옴.
for dataset in data_dir_list:
    if dataset in '.DS_Store':
            continue
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.        
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        #input_img=cv2.cvtColor(input_img, cv2.COLOR_BGR2GRAY)
        input_img_resize=cv2.resize(input_img,(48,48))
        img_data_list.append(input_img_resize)
        
img_data = np.array(img_data_list)
img_data = img_data.astype('float32')
img_data = img_data/255 #normalization
print(img_data.shape)

#데이터 라벨링

num_classes = 7

#전체 이미지의 개수를 받아옴(981개)
num_of_samples = img_data.shape[0]

#샘플 이미지의 개수만큼 데이터가 1인 numpy array를 생성. shape : (981,)
labels = np.ones((num_of_samples,),dtype='int64')

# print(labels.shape)
labels[0:134]=0 #135 anger:0 으로 라벨링
labels[135:188]=1 #54 contempt:1 으로 라벨링
labels[189:365]=2 #177 disgust:2 으로 라벨링
labels[366:440]=3 #75 fear:3 으로 라벨링
labels[441:647]=4 #207 happy:4 으로 라벨링
labels[648:731]=5 #84 sadness:5 으로 라벨링
labels[732:980]=6 #249 surprise:6 으로 라벨링

# 카테고리 리스트로 선언
names = file_list

#argmax방식으로 리턴    
def getLabel_ByArgmax(preds):
    index = np.argmax(preds)
    return names[index]
    

# 훈련, 검증 데이터 셋 분리.

#원핫 인코딩 /  (파라미터 값, 0으로된 배열의 크기)
# 0: 1000000
# 1: 0100000
# 2: 0010000
#하나의 이미지에 대해 0과 1로 라벨링된(원핫인코딩된)배열을 리턴받음.
Y = np_utils.to_categorical(labels, num_classes)

#Shuffle the dataset
x,y = shuffle(img_data,Y, random_state=2)
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

#모델 생성 및 요약
import creat_model as cm

model_custom = cm.create_model()

model_custom.summary()

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rotation_range = 40,
    zoom_range = 0.2,
    horizontal_flip = True,
    fill_mode = 'nearest')

train_generator = train_datagen.flow(X_train,y_train,batch_size=8,shuffle=True)

model=Sequential([
                  Conv2D(64,3,activation='relu',kernel_initializer='he_normal',input_shape=(48,48,3)),
                  MaxPooling2D(3),
                  Conv2D(128,3,activation='relu',kernel_initializer='he_normal'),
                  Conv2D(256,3,activation='relu',kernel_initializer='he_normal'),
                  MaxPooling2D(3),
                  Flatten(),
                  Dense(256,activation='relu'),
                  Dense(7,activation='softmax',kernel_initializer='glorot_normal')
                  
])

es = EarlyStopping(
    monitor='val_accuracy', min_delta=0.0001, patience=10, verbose=2,
    mode='max', baseline=None, restore_best_weights=True
)
lr = ReduceLROnPlateau(
    monitor='val_accuracy', factor=0.1, patience=5, verbose=2,
    mode='max', min_delta=1e-5, cooldown=0, min_lr=0
)

callbacks = [es, lr]

model.summary()

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

history = model.fit(train_generator, batch_size=8 , epochs=20, validation_data = (X_test, y_test), callbacks = [callbacks],shuffle=True)
# Out:
# file list: ['happy', 'contempt', 'fear', 'surprise', 'sadness', 'anger', 'disgust']
# Loaded the images of dataset-happy
#
# Loaded the images of dataset-contempt
#
# Loaded the images of dataset-fear
#
# Loaded the images of dataset-surprise
#
# Loaded the images of dataset-sadness
#
# Loaded the images of dataset-anger
#
# Loaded the images of dataset-disgust
#
# (981, 48, 48, 3)
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_74 (Conv2D)          (None, 48, 48, 6)         456
#
#  max_pooling2d_70 (MaxPoolin  (None, 24, 24, 6)        0
#  g2D)
#
#  conv2d_75 (Conv2D)          (None, 24, 24, 16)        2416
#
#  activation_20 (Activation)  (None, 24, 24, 16)        0
#
#  max_pooling2d_71 (MaxPoolin  (None, 12, 12, 16)       0
#  g2D)
#
#  conv2d_76 (Conv2D)          (None, 10, 10, 64)        9280
#
#  max_pooling2d_72 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  flatten_24 (Flatten)        (None, 1600)              0
#
#  dense_48 (Dense)            (None, 128)               204928
#
#  dropout_20 (Dropout)        (None, 128)               0
#
#  dense_49 (Dense)            (None, 7)                 903
#
# =================================================================
# Total params: 217,983
# Trainable params: 217,983
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_77 (Conv2D)          (None, 46, 46, 64)        1792
#
#  max_pooling2d_73 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_78 (Conv2D)          (None, 13, 13, 128)       73856
#
#  conv2d_79 (Conv2D)          (None, 11, 11, 256)       295168
#
#  max_pooling2d_74 (MaxPoolin  (None, 3, 3, 256)        0
#  g2D)
#
#  flatten_25 (Flatten)        (None, 2304)              0
#
#  dense_50 (Dense)            (None, 256)               590080
#
#  dense_51 (Dense)            (None, 7)                 1799
#
# =================================================================
# Total params: 962,695
# Trainable params: 962,695
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2022-11-20 00:47:41.640063: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In [138], line 157
#     153 model.summary()
#     155 model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
# --> 157 history = model.fit(train_generator, batch_size=8 , epochs=20, validation_data = (X_test, y_test), callbacks = [callbacks],shuffle=True)
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits' defined at (most recent call last):
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/traitlets/config/application.py", line 978, in launch_instance
#       app.start()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#       self._run_once()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#       handle._run()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2885, in run_cell
#       result = self._run_cell(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#       return runner(coro)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3139, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3318, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3378, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/zh/v9f2b_v55ml9_yp9qr_69lk40000gn/T/ipykernel_7464/1755166853.py", line 157, in <module>
#       history = model.fit(train_generator, batch_size=8 , epochs=20, validation_data = (X_test, y_test), callbacks = [callbacks],shuffle=True)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 994, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1052, in compute_loss
#       return self.compiled_loss(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 152, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 272, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 2084, in sparse_categorical_crossentropy
#       return backend.sparse_categorical_crossentropy(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/backend.py", line 5630, in sparse_categorical_crossentropy
#       res = tf.nn.sparse_softmax_cross_entropy_with_logits(
# Node: 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits'
# Detected at node 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits' defined at (most recent call last):
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/traitlets/config/application.py", line 978, in launch_instance
#       app.start()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#       self._run_once()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#       handle._run()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2885, in run_cell
#       result = self._run_cell(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#       return runner(coro)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3139, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3318, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3378, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/zh/v9f2b_v55ml9_yp9qr_69lk40000gn/T/ipykernel_7464/1755166853.py", line 157, in <module>
#       history = model.fit(train_generator, batch_size=8 , epochs=20, validation_data = (X_test, y_test), callbacks = [callbacks],shuffle=True)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 994, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1052, in compute_loss
#       return self.compiled_loss(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 152, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 272, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 2084, in sparse_categorical_crossentropy
#       return backend.sparse_categorical_crossentropy(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/backend.py", line 5630, in sparse_categorical_crossentropy
#       res = tf.nn.sparse_softmax_cross_entropy_with_logits(
# Node: 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits'
# 2 root error(s) found.
#   (0) INVALID_ARGUMENT:  logits and labels must have the same first dimension, got logits shape [8,7] and labels shape [56]
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]]
# 	 [[Equal/_21]]
#   (1) INVALID_ARGUMENT:  logits and labels must have the same first dimension, got logits shape [8,7] and labels shape [56]
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_706677]

# %% [markdown]
# # 데이터셋의 이미지 크기 정보 알아오기

# %%
import os
import cv2
data_path = './Input/CK+48'
file_list = os.listdir(data_path)
# file_list.remove('./DS_Store')
print("file list:",file_list)

num_epoch=10

img_data_list=[]

data_dir_list = os.listdir(data_path)

#우리가 파일을 만든 순서가 아닌 컴퓨터가 지가 읽는 순서대로 파일을 불러옴.
for dataset in data_dir_list:
    if dataset in '.DS_Store':
            continue
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.        
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        print(input_img.shape)
#         input_img_resize=cv2.resize(input_img,(48,48))
#         img_data_list.append(input_img_resize)
# Out:
# file list: ['happy', '.DS_Store', 'contempt', 'fear', 'surprise', 'sadness', 'anger', 'disgust']
# Loaded the images of dataset-happy
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-contempt
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-fear
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-surprise
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-sadness
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-anger
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-disgust
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)

# %%
additional_data_path = './image'
additional_data_list = os.listdir(additional_data_path)
for dataset in additional_data_list:
    img_list=os.listdir(additional_data_path+'/'+ dataset)
#     print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.        
        input_img=cv2.imread(additional_data_path + '/'+ dataset + '/'+ img )
        
        print(input_img.shape)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In [4], line 4
#       2 additional_data_list = os.listdir(additional_data_path)
#       3 for dataset in additional_data_list:
# ----> 4     img_list=os.listdir(additional_data_path+'/'+ dataset)
#       5 #     print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
#       6     for img in img_list:
#       7         #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.
#
# NotADirectoryError: [Errno 20] Not a directory: './image/croped_image817.jpg'

# %%
def show_40sample_images(X_train, y_train):
    # 이 데이터셋에 있는 샘플 이미지를 몇 개 출력해 보죠:
    n_rows = 4
    n_cols = 10
    plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
    for row in range(n_rows):
        for col in range(n_cols):
            index = n_cols * row + col
            plt.subplot(n_rows, n_cols, index + 1)
            plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
            plt.axis('off')
            plt.title(class_names[int(y_train[index])], fontsize=12)
    plt.subplots_adjust(wspace=0.2, hspace=0.5)
    plt.show()

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os,cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#matplotlib을 통해 보여줄 그래프의 크기를 직접 지정해 준것.
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import tensorflow as tf

from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import *
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
import os
data_path = './Input/CK+48'
file_list = os.listdir(data_path)
file_list.remove('.DS_Store')
print("file list:",file_list)

# Any results you write to the current directory are saved as output

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.datasets import make_classification
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

#디렉토리에서 이미지를 추출하기

num_epoch=10

img_data_list=[]

labels = []
class_names=['happy', 'contempt', 'fear', 'surprise', 'sadness', 'anger', 'disgust']
labeled = 0
img_count = 0
#우리가 파일을 만든 순서가 아닌 컴퓨터가 지가 읽는 순서대로 파일을 불러옴.
for dataset in file_list:
    img_one_cat_list = []
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.        
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        input_img_resize=cv2.resize(input_img,(48,48),interpolation=cv2.INTER_AREA)
        img_data_list.append(input_img_resize)
        img_one_cat_list.append(input_img_resize)
        img_one_cat_list = np.array(img_one_cat_list)
    print(img_one_cat_list.shape)
    fig,axes = plt.subplots(1,10)
    for i in range(10):
        axes[1,i].imshow(img_one_cat_list[i], cmap="binary", interpolation="nearest")
#             plt.imshow(img_one_cat_list[index], cmap="binary", interpolation="nearest")
#             plt.axis('off')
#             plt.title(class_names[col])
#     plt.subplots_adjust(wspace=0.2, hspace=0.5)
    plt.show()

    
    #라벨링 넘파이 배열 생성 
    for label in range(len(img_one_cat_list)):
        labels.append(labeled)

    labeled += 1

img_data = np.array(img_data_list)
labels = np.array(labels)
# Out:
# file list: ['happy', 'contempt', 'fear', 'surprise', 'sadness', 'anger', 'disgust']
# Loaded the images of dataset-happy
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [1], line 56
#      54     input_img_resize=cv2.resize(input_img,(48,48),interpolation=cv2.INTER_AREA)
#      55     img_data_list.append(input_img_resize)
# ---> 56     img_one_cat_list.append(input_img_resize)
#      57     img_one_cat_list = np.array(img_one_cat_list)
#      58 print(img_one_cat_list.shape)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
def build_dcnn(input_shape, num_classes):
    model_in = Input(shape=input_shape, name="input")
    
    conv2d_1 = Conv2D(
        filters=64,
        kernel_size=(3,3),
        activation='relu',
        padding='same',
        kernel_initializer='he_normal',
        name='conv2d_1'
    )(model_in)
    batchnorm_1 = BatchNormalization(name='batchnorm_1')(conv2d_1)
    conv2d_2 = Conv2D(
        filters=64,
        kernel_size=(3,3),
        activation='relu',
        padding='same',
        kernel_initializer='he_normal',
        name='conv2d_2'
    )(batchnorm_1)
    batchnorm_2 = BatchNormalization(name='batchnorm_2')(conv2d_2)
    
    maxpool2d_1 = MaxPooling2D(pool_size=(2,2), name='maxpool2d_1')(batchnorm_2)
    dropout_1 = Dropout(0.3, name='dropout_1')(maxpool2d_1)

    conv2d_3 = Conv2D(
        filters=128,
        kernel_size=(3,3),
        activation='relu',
        padding='same',
        kernel_initializer='he_normal',
        name='conv2d_3'
    )(dropout_1)
    batchnorm_3 = BatchNormalization(name='batchnorm_3')(conv2d_3)
    conv2d_4 = Conv2D(
        filters=128,
        kernel_size=(3,3),
        activation='relu',
        padding='same',
        kernel_initializer='he_normal',
        name='conv2d_4'
    )(batchnorm_3)
    batchnorm_4 = BatchNormalization(name='batchnorm_4')(conv2d_4)
    
    maxpool2d_2 = MaxPooling2D(pool_size=(2,2), name='maxpool2d_2')(batchnorm_4)
    dropout_2 = Dropout(0.3, name='dropout_2')(maxpool2d_2)

    conv2d_5 = Conv2D(
        filters=256,
        kernel_size=(3,3),
        activation='relu',
        padding='same',
        kernel_initializer='he_normal',
        name='conv2d_5'
    )(dropout_2)
    batchnorm_5 = BatchNormalization(name='batchnorm_5')(conv2d_5)
    conv2d_6 = Conv2D(
        filters=256,
        kernel_size=(3,3),
        activation='relu',
        padding='same',
        kernel_initializer='he_normal',
        name='conv2d_6'
    )(batchnorm_5)
    batchnorm_6 = BatchNormalization(name='batchnorm_6')(conv2d_6)
    
    maxpool2d_3 = MaxPooling2D(pool_size=(2,2), name='maxpool2d_3')(batchnorm_6)
    dropout_3 = Dropout(0.3, name='dropout_3')(maxpool2d_3)

    flatten = Flatten(name='flatten')(dropout_3)
    
    dense_1 = Dense(
        128,
        activation='relu',
        kernel_initializer='he_normal',
        name='dense1'
    )(flatten)
    batchnorm_7 = BatchNormalization(name='batchnorm_7')(dense_1)
    dropout_4 = Dropout(0.4, name='dropout_4')(batchnorm_7)

    model_out = Dense(
        num_classes,
        activation='softmax',
        name='out_layer'
    )(dropout_4)

    model = Model(inputs=model_in, outputs=model_out, name="DCNN")
    
    return model
INPUT_SHAPE = (48, 48, 1)
optim = optimizers.Adam(0.001)

model = build_dcnn(input_shape=(48,48,1), num_classes=len(label_to_text))
model.compile(
        loss='categorical_crossentropy',
        optimizer=optim,
        metrics=['accuracy']
)
