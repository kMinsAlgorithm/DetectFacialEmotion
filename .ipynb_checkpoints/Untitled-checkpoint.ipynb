# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os,cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#matplotlib을 통해 보여줄 그래프의 크기를 직접 지정해 준것.
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import tensorflow as tf

from keras.utils import np_utils
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
from keras.models import Sequential
from keras.layers import *
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
import os
data_path = './Input/CK+48'
file_list = os.listdir(data_path)
file_list.remove('.DS_Store')

print("file list:",file_list)

# Any results you write to the current directory are saved as output

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.datasets import make_classification
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

#디렉토리에서 이미지를 추출하기

num_epoch=10

img_data_list=[]

labels = []
labeled = 0
img_count = 0
#우리가 파일을 만든 순서가 아닌 컴퓨터가 지가 읽는 순서대로 파일을 불러옴.
for dataset in file_list:
    img_one_cat_len = 0
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.        
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        input_img_resize=cv2.resize(input_img,(300,300),interpolation=cv2.INTER_LINEAR)
#         input_img_gray = cv2.cvtColor(input_img_resize, cv2.COLOR_RGB2GRAY)
        img_data_list.append(input_img_resize)
        img_one_cat_len +=1
    #라벨링 넘파이 배열 생성 
    for label in range(img_one_cat_len):
        labels.append(labeled)

    labeled += 1

img_data = np.array(img_data_list)
labels = np.array(labels)

#이미지 데이터 정규화

img_data = img_data.astype('float32')
img_data = img_data/255 #normalization
print(img_data.shape)

num_classes = len(file_list)

# 카테고리 리스트로 선언
names = file_list

#라벨 이름 리턴
def getLabel(labels): 
    return names[labels.index(1)]
def getLabel_Incoding(preds):
    index = np.argmax(preds)
    return names[index-1]    

# 훈련, 검증 데이터 셋 분리.

#원핫 인코딩 /  (파라미터 값, 0으로된 배열의 크기)
# 0: 1000000
# 1: 0100000
# 2: 0010000
#하나의 이미지에 대해 0과 1로 라벨링된(원핫인코딩된)배열을 리턴받음.
Y = np_utils.to_categorical(labels, num_classes)

#Shuffle the dataset
x,y = shuffle(img_data,Y, random_state=2)
# Split the dataset
# X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

#모델 생성 및 요약
# import creat_model as cm
def create_model(num_output):
    model = Sequential()
    input_shape=(300,300,3)
#     input_shape=(300,300)
    model.add(Conv2D(16, (3, 3), input_shape=input_shape, padding='same',kernel_initializer='he_normal', activation = 'relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3),padding='same',kernel_initializer='he_normal', activation = 'relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding='same',kernel_initializer='he_normal', activation = 'relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

#     model.add(Conv2D(64, (3, 3), padding='same',kernel_initializer='he_normal', activation = 'relu'))
#     model.add(BatchNormalization())
#     model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3),padding='same',kernel_initializer='he_normal', activation = 'relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

#     model.add(Conv2D(32, (3, 3),padding='same',kernel_initializer='he_normal', activation = 'relu'))
#     model.add(BatchNormalization())
#     model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(16, (3, 3),padding='same',kernel_initializer='he_normal', activation = 'relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    model.add(Dense(256, kernel_initializer='he_normal', activation = 'relu'))
    model.add(Dropout(0.5))
#     model.add(Dense(128, kernel_initializer='he_normal', activation = 'relu'))
    model.add(Dense(num_output, activation = 'softmax'))

    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    
    return model

model_custom = create_model(num_classes)

model_custom.summary()

#Conduct k-Fold Cross-validation

from sklearn.model_selection import KFold

# kfold 교차 검증
# 데이터가 적은 데이터 셋에 대하여 정확도를 향상 시키기 위함.
# 이는 기존에 Training / Validation / Test 세개의 집단으로 분류하는것 보다 Training / Test로만 분류할때 학습 데이터 셋이 더 많기 때문.

# 5개의 폴드 세트로 분리하는 K Fold 객체와 폴드 세트별 정확도를 담을 리스트 객체 생성.
kf = KFold(n_splits=10, shuffle=False)

#Data Augmentation 기능 / 데이터 증강 기법
#모델의 성능을 높이면서 오버피팅을 극복하기 위해 학습 데이터의 다양성을 늘리기 위함.
#하나의 원본 이미지를 다양항 버전으로 만들어 학습시키는 것.
#대표적인 데이터 증강 기법으로는 원본 이미지를 수평 또는 수직 반전 시키는 방법, 회전시키는 방법, 일부를 자르는 방법,RGB채널 순서를 바꾸거나 
#픽셀값을 변경하여 원본 이미지의 색조를 변경시키는 것들이 있음.
#이러한 이미지 증강 기법을 tf.keras의 ImageDataGenerator 가 대신해줌.
#이 툴 이외에 Data Albumenation이나, ImgAug, Tensorflow Image Library 등 다양한 데이터 증강 기법 툴들이 있음.

from keras.preprocessing.image import ImageDataGenerator

# 이미지 증강법 1단계.ImageDataGenerator 객체(aug)를 생성하면서 증강을 수행할 유형들을 지정.
aug = ImageDataGenerator(
    rotation_range = 40,
    zoom_range = 0.2,
    horizontal_flip = True,
    fill_mode = 'nearest')

#Training Model 
BS = 8 # batch size
EPOCHS = 100 # epochs

result = []
scores_loss = []
scores_acc = []
k_no = 0

#Kfold 객체의 split()을 호출하면 폴드별 학습용, 검증용 테스트의 로우 인덱스를 array로 반환
#split()이 알아서 학습용 검증용 데이터를 나누어줌. 위에서 k=5라고 지정한 경우 for문이 5번 돌아 가면서 학습용, 검증용 데이터를 나누어 줌.
for train_index, test_index in kf.split(x):
    #Kfold 객채의 split()으로 반환된 인덱스를 이용해 학습용, 검증용 테스트 데이터를 추출함.
    X_Train,X_Test = x[train_index], x[test_index]
    Y_Train,Y_Test = y[train_index], y[test_index]

    # 최적의 모델을 저장할 경로
    file_path = "./weights_best_emotion_detect4.h5"
    # 콜백 함수. (체크포인트, 조기 종료 선언)
    checkpoint = ModelCheckpoint(file_path, monitor='loss', save_best_only=True, mode='min')
    early = EarlyStopping(monitor="loss", mode="min", patience=8)

    callbacks_list = [checkpoint, early]

    #이미지 증강법 2단계 aug.flow(X,y,batch_size=,shuffle=) : X(훈련 이미지),y(라벨), 이미지를 한번에 몇개 업로드 시킬지에 대한 배치 사이즈,데이터 셔플 유무
    #flow 메소드로 생성한 객체는 Numpy Array Iterator 객체로 우리가 흔히 아는 Python Iterator처럼 loop문이나 next()함수를 사용해 Iterator 안에 데이터를 하나씩 호출 가능.

    hist = model_custom.fit_generator(aug.flow(X_Train, Y_Train), epochs=EPOCHS,validation_data=(X_Test, Y_Test), callbacks=callbacks_list)
    # model.fit(X_Train, Y_Train, batch_size=batch_size, epochs=epochs, validation_data=(X_Test, Y_Test), verbose=1)
    
#     model_custom.load_weights(file_path)
    result.append(model_custom.predict(X_Test))
    score = model_custom.evaluate(X_Test,Y_Test)
    scores_loss.append(score[0])
    scores_acc.append(score[1])
    k_no+=1

print(scores_acc,scores_loss)
# Out:
# file list: ['happy', 'surprise', 'sadness', 'anger']
# Loaded the images of dataset-happy
#
# Loaded the images of dataset-surprise
#
# Loaded the images of dataset-sadness
#
# Loaded the images of dataset-anger
#
# (789, 300, 300, 3)
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_37 (Conv2D)          (None, 300, 300, 32)      896
#
#  batch_normalization_36 (Bat  (None, 300, 300, 32)     128
#  chNormalization)
#
#  max_pooling2d_36 (MaxPoolin  (None, 150, 150, 32)     0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 150, 150, 64)      18496
#
#  batch_normalization_37 (Bat  (None, 150, 150, 64)     256
#  chNormalization)
#
#  max_pooling2d_37 (MaxPoolin  (None, 75, 75, 64)       0
#  g2D)
#
#  conv2d_39 (Conv2D)          (None, 75, 75, 32)        18464
#
#  batch_normalization_38 (Bat  (None, 75, 75, 32)       128
#  chNormalization)
#
#  max_pooling2d_38 (MaxPoolin  (None, 37, 37, 32)       0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 37, 37, 16)        4624
#
#  batch_normalization_39 (Bat  (None, 37, 37, 16)       64
#  chNormalization)
#
#  max_pooling2d_39 (MaxPoolin  (None, 18, 18, 16)       0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 5184)              0
#
#  dense_16 (Dense)            (None, 256)               1327360
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_17 (Dense)            (None, 4)                 1028
#
# =================================================================
# Total params: 1,371,444
# Trainable params: 1,371,156
# Non-trainable params: 288
# _________________________________________________________________
# /var/folders/zh/v9f2b_v55ml9_yp9qr_69lk40000gn/T/ipykernel_94752/303946595.py:206: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model_custom.fit_generator(aug.flow(X_Train, Y_Train), epochs=EPOCHS,validation_data=(X_Test, Y_Test), callbacks=callbacks_list)
# Epoch 1/100
# 2022-11-28 15:16:30.717291: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 23/23 [==============================] - ETA: 0s - loss: 2.0720 - accuracy: 0.4662
# 2022-11-28 15:16:41.200954: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 23/23 [==============================] - 11s 323ms/step - loss: 2.0720 - accuracy: 0.4662 - val_loss: 1.6136 - val_accuracy: 0.3797
# Epoch 2/100
# 23/23 [==============================] - 7s 312ms/step - loss: 0.9740 - accuracy: 0.6507 - val_loss: 1.2579 - val_accuracy: 0.4430
# Epoch 3/100
# 23/23 [==============================] - 7s 306ms/step - loss: 0.7091 - accuracy: 0.7324 - val_loss: 1.5489 - val_accuracy: 0.2658
# Epoch 4/100
# 23/23 [==============================] - 7s 298ms/step - loss: 0.5928 - accuracy: 0.7746 - val_loss: 1.6653 - val_accuracy: 0.2152
# Epoch 5/100
# 23/23 [==============================] - 7s 297ms/step - loss: 0.4768 - accuracy: 0.8141 - val_loss: 1.7264 - val_accuracy: 0.2405
# Epoch 6/100
# 23/23 [==============================] - 7s 305ms/step - loss: 0.5241 - accuracy: 0.7972 - val_loss: 2.1257 - val_accuracy: 0.2658
# Epoch 7/100
# 23/23 [==============================] - 7s 314ms/step - loss: 0.4501 - accuracy: 0.8211 - val_loss: 1.9700 - val_accuracy: 0.3671
# Epoch 8/100
# 23/23 [==============================] - 7s 305ms/step - loss: 0.4853 - accuracy: 0.8141 - val_loss: 2.0224 - val_accuracy: 0.3165
# Epoch 9/100
# 23/23 [==============================] - 7s 309ms/step - loss: 0.4047 - accuracy: 0.8437 - val_loss: 1.8880 - val_accuracy: 0.3291
# Epoch 10/100
# 23/23 [==============================] - 7s 294ms/step - loss: 0.3586 - accuracy: 0.8521 - val_loss: 0.9288 - val_accuracy: 0.5443
# Epoch 11/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.3737 - accuracy: 0.8535 - val_loss: 1.0675 - val_accuracy: 0.5063
# Epoch 12/100
# 23/23 [==============================] - 7s 296ms/step - loss: 0.3446 - accuracy: 0.8577 - val_loss: 0.7804 - val_accuracy: 0.6709
# Epoch 13/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.3104 - accuracy: 0.8704 - val_loss: 0.7760 - val_accuracy: 0.6076
# Epoch 14/100
# 23/23 [==============================] - 7s 287ms/step - loss: 0.4160 - accuracy: 0.8225 - val_loss: 0.6205 - val_accuracy: 0.6835
# Epoch 15/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.3726 - accuracy: 0.8465 - val_loss: 0.6641 - val_accuracy: 0.7595
# Epoch 16/100
# 23/23 [==============================] - 7s 298ms/step - loss: 0.3050 - accuracy: 0.8803 - val_loss: 0.5888 - val_accuracy: 0.7595
# Epoch 17/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.3053 - accuracy: 0.8634 - val_loss: 0.4865 - val_accuracy: 0.7089
# Epoch 18/100
# 23/23 [==============================] - 7s 310ms/step - loss: 0.3192 - accuracy: 0.8761 - val_loss: 0.4517 - val_accuracy: 0.8481
# Epoch 19/100
# 23/23 [==============================] - 7s 295ms/step - loss: 0.2600 - accuracy: 0.9000 - val_loss: 0.5033 - val_accuracy: 0.7595
# Epoch 20/100
# 23/23 [==============================] - 7s 284ms/step - loss: 0.2749 - accuracy: 0.8775 - val_loss: 0.4327 - val_accuracy: 0.7722
# Epoch 21/100
# 23/23 [==============================] - 7s 293ms/step - loss: 0.2621 - accuracy: 0.8958 - val_loss: 0.5165 - val_accuracy: 0.7595
# Epoch 22/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.2486 - accuracy: 0.9000 - val_loss: 0.2970 - val_accuracy: 0.8734
# Epoch 23/100
# 23/23 [==============================] - 7s 285ms/step - loss: 0.2771 - accuracy: 0.8915 - val_loss: 0.1756 - val_accuracy: 0.9494
# Epoch 24/100
# 23/23 [==============================] - 7s 285ms/step - loss: 0.2596 - accuracy: 0.8873 - val_loss: 0.1736 - val_accuracy: 0.9241
# Epoch 25/100
# 23/23 [==============================] - 7s 285ms/step - loss: 0.2559 - accuracy: 0.8915 - val_loss: 0.4727 - val_accuracy: 0.7848
# Epoch 26/100
# 23/23 [==============================] - 7s 285ms/step - loss: 0.2705 - accuracy: 0.8972 - val_loss: 0.9957 - val_accuracy: 0.6456
# Epoch 27/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.2771 - accuracy: 0.8915 - val_loss: 0.3138 - val_accuracy: 0.8608
# Epoch 28/100
# 23/23 [==============================] - 7s 300ms/step - loss: 0.2185 - accuracy: 0.9183 - val_loss: 0.2845 - val_accuracy: 0.8734
# Epoch 29/100
# 23/23 [==============================] - 7s 296ms/step - loss: 0.1978 - accuracy: 0.9197 - val_loss: 0.2339 - val_accuracy: 0.9241
# Epoch 30/100
# 23/23 [==============================] - 7s 299ms/step - loss: 0.1758 - accuracy: 0.9324 - val_loss: 0.2051 - val_accuracy: 0.9367
# Epoch 31/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.1632 - accuracy: 0.9451 - val_loss: 0.2664 - val_accuracy: 0.9114
# Epoch 32/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.2215 - accuracy: 0.9099 - val_loss: 0.1710 - val_accuracy: 0.9620
# Epoch 33/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.1766 - accuracy: 0.9183 - val_loss: 0.2385 - val_accuracy: 0.8987
# Epoch 34/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.2035 - accuracy: 0.9225 - val_loss: 0.2118 - val_accuracy: 0.9114
# Epoch 35/100
# 23/23 [==============================] - 7s 284ms/step - loss: 0.1815 - accuracy: 0.9380 - val_loss: 0.2172 - val_accuracy: 0.9367
# Epoch 36/100
# 23/23 [==============================] - 7s 285ms/step - loss: 0.1894 - accuracy: 0.9141 - val_loss: 0.5163 - val_accuracy: 0.8101
# Epoch 37/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.1867 - accuracy: 0.9296 - val_loss: 0.1249 - val_accuracy: 0.9494
# Epoch 38/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.1732 - accuracy: 0.9268 - val_loss: 0.2326 - val_accuracy: 0.9114
# Epoch 39/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.1924 - accuracy: 0.9169 - val_loss: 0.1764 - val_accuracy: 0.9494
# 1/3 [=========>....................] - ETA: 0s
# 2022-11-28 15:21:05.264857: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 0s 46ms/step
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1764 - accuracy: 0.9494
# Epoch 1/100
# 23/23 [==============================] - 8s 339ms/step - loss: 0.1650 - accuracy: 0.9296 - val_loss: 0.0602 - val_accuracy: 0.9873
# Epoch 2/100
# 23/23 [==============================] - 9s 367ms/step - loss: 0.1383 - accuracy: 0.9465 - val_loss: 0.0426 - val_accuracy: 0.9873
# Epoch 3/100
# 23/23 [==============================] - 7s 306ms/step - loss: 0.1264 - accuracy: 0.9465 - val_loss: 0.0828 - val_accuracy: 0.9747
# Epoch 4/100
# 23/23 [==============================] - 7s 287ms/step - loss: 0.1637 - accuracy: 0.9380 - val_loss: 0.1519 - val_accuracy: 0.9494
# Epoch 5/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.1570 - accuracy: 0.9380 - val_loss: 0.0312 - val_accuracy: 1.0000
# Epoch 6/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.1465 - accuracy: 0.9507 - val_loss: 0.0625 - val_accuracy: 0.9747
# Epoch 7/100
# 23/23 [==============================] - 7s 296ms/step - loss: 0.1663 - accuracy: 0.9352 - val_loss: 0.0563 - val_accuracy: 0.9620
# Epoch 8/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.1159 - accuracy: 0.9549 - val_loss: 0.0689 - val_accuracy: 0.9747
# Epoch 9/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.1500 - accuracy: 0.9451 - val_loss: 0.0433 - val_accuracy: 0.9873
# Epoch 10/100
# 23/23 [==============================] - 7s 293ms/step - loss: 0.1194 - accuracy: 0.9563 - val_loss: 0.0386 - val_accuracy: 0.9873
# Epoch 11/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.1075 - accuracy: 0.9676 - val_loss: 0.0681 - val_accuracy: 0.9873
# Epoch 12/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.1144 - accuracy: 0.9549 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 13/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.1510 - accuracy: 0.9366 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 14/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.1681 - accuracy: 0.9380 - val_loss: 0.0214 - val_accuracy: 1.0000
# Epoch 15/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.1227 - accuracy: 0.9549 - val_loss: 0.0481 - val_accuracy: 0.9747
# Epoch 16/100
# 23/23 [==============================] - 7s 287ms/step - loss: 0.1339 - accuracy: 0.9521 - val_loss: 0.0323 - val_accuracy: 0.9873
# Epoch 17/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.1030 - accuracy: 0.9577 - val_loss: 0.0305 - val_accuracy: 0.9873
# Epoch 18/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.1193 - accuracy: 0.9577 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 19/100
# 23/23 [==============================] - 7s 287ms/step - loss: 0.1761 - accuracy: 0.9408 - val_loss: 0.3509 - val_accuracy: 0.8987
# Epoch 20/100
# 23/23 [==============================] - 7s 297ms/step - loss: 0.1955 - accuracy: 0.9310 - val_loss: 0.1298 - val_accuracy: 0.9620
# Epoch 21/100
# 23/23 [==============================] - 7s 287ms/step - loss: 0.1268 - accuracy: 0.9648 - val_loss: 0.1055 - val_accuracy: 0.9241
# Epoch 22/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.1191 - accuracy: 0.9549 - val_loss: 0.4853 - val_accuracy: 0.8101
# Epoch 23/100
# 23/23 [==============================] - 7s 299ms/step - loss: 0.1841 - accuracy: 0.9268 - val_loss: 0.0651 - val_accuracy: 0.9747
# Epoch 24/100
# 23/23 [==============================] - 7s 293ms/step - loss: 0.1217 - accuracy: 0.9577 - val_loss: 0.0849 - val_accuracy: 0.9494
# Epoch 25/100
# 23/23 [==============================] - 7s 294ms/step - loss: 0.1258 - accuracy: 0.9535 - val_loss: 0.1235 - val_accuracy: 0.9367
# 3/3 [==============================] - 0s 38ms/step
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1235 - accuracy: 0.9367
# Epoch 1/100
# 23/23 [==============================] - 7s 308ms/step - loss: 0.1663 - accuracy: 0.9507 - val_loss: 0.0738 - val_accuracy: 0.9747
# Epoch 2/100
# 23/23 [==============================] - 7s 298ms/step - loss: 0.1553 - accuracy: 0.9521 - val_loss: 0.1404 - val_accuracy: 0.9494
# Epoch 3/100
# 23/23 [==============================] - 7s 297ms/step - loss: 0.1320 - accuracy: 0.9479 - val_loss: 0.0867 - val_accuracy: 0.9747
# Epoch 4/100
# 23/23 [==============================] - 7s 294ms/step - loss: 0.0983 - accuracy: 0.9690 - val_loss: 0.0818 - val_accuracy: 0.9620
# Epoch 5/100
# 23/23 [==============================] - 7s 287ms/step - loss: 0.1554 - accuracy: 0.9352 - val_loss: 0.0977 - val_accuracy: 0.9494
# Epoch 6/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.1514 - accuracy: 0.9451 - val_loss: 0.0755 - val_accuracy: 0.9620
# Epoch 7/100
# 23/23 [==============================] - 7s 303ms/step - loss: 0.1119 - accuracy: 0.9549 - val_loss: 0.2041 - val_accuracy: 0.9114
# Epoch 8/100
# 23/23 [==============================] - 7s 312ms/step - loss: 0.1448 - accuracy: 0.9507 - val_loss: 0.2708 - val_accuracy: 0.9114
# Epoch 9/100
# 23/23 [==============================] - 7s 308ms/step - loss: 0.1142 - accuracy: 0.9620 - val_loss: 0.1738 - val_accuracy: 0.8987
# Epoch 10/100
# 23/23 [==============================] - 7s 314ms/step - loss: 0.1036 - accuracy: 0.9606 - val_loss: 0.0845 - val_accuracy: 0.9747
# Epoch 11/100
# 23/23 [==============================] - 7s 311ms/step - loss: 0.1100 - accuracy: 0.9577 - val_loss: 0.3971 - val_accuracy: 0.8481
# Epoch 12/100
# 23/23 [==============================] - 7s 316ms/step - loss: 0.1113 - accuracy: 0.9606 - val_loss: 0.1224 - val_accuracy: 0.9620
# 3/3 [==============================] - 0s 40ms/step
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1224 - accuracy: 0.9620
# Epoch 1/100
# 23/23 [==============================] - 8s 331ms/step - loss: 0.0913 - accuracy: 0.9648 - val_loss: 0.1495 - val_accuracy: 0.9367
# Epoch 2/100
# 23/23 [==============================] - 7s 309ms/step - loss: 0.0559 - accuracy: 0.9775 - val_loss: 0.0834 - val_accuracy: 0.9620
# Epoch 3/100
# 23/23 [==============================] - 7s 306ms/step - loss: 0.0876 - accuracy: 0.9662 - val_loss: 0.1610 - val_accuracy: 0.9367
# Epoch 4/100
# 23/23 [==============================] - 7s 318ms/step - loss: 0.0649 - accuracy: 0.9704 - val_loss: 0.0503 - val_accuracy: 0.9747
# Epoch 5/100
# 23/23 [==============================] - 7s 306ms/step - loss: 0.0576 - accuracy: 0.9789 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 6/100
# 23/23 [==============================] - 7s 295ms/step - loss: 0.0843 - accuracy: 0.9732 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 7/100
# 23/23 [==============================] - 7s 298ms/step - loss: 0.0579 - accuracy: 0.9761 - val_loss: 0.0258 - val_accuracy: 1.0000
# Epoch 8/100
# 23/23 [==============================] - 7s 304ms/step - loss: 0.0782 - accuracy: 0.9732 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 9/100
# 23/23 [==============================] - 7s 306ms/step - loss: 0.0986 - accuracy: 0.9662 - val_loss: 0.3207 - val_accuracy: 0.9114
# Epoch 10/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.0609 - accuracy: 0.9775 - val_loss: 0.0092 - val_accuracy: 1.0000
# 3/3 [==============================] - 0s 38ms/step
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 1/100
# 23/23 [==============================] - 7s 303ms/step - loss: 0.0831 - accuracy: 0.9690 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 2/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.0600 - accuracy: 0.9775 - val_loss: 0.1205 - val_accuracy: 0.9494
# Epoch 3/100
# 23/23 [==============================] - 7s 317ms/step - loss: 0.0536 - accuracy: 0.9803 - val_loss: 0.6294 - val_accuracy: 0.8354
# Epoch 4/100
# 23/23 [==============================] - 7s 304ms/step - loss: 0.0963 - accuracy: 0.9704 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 5/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.0886 - accuracy: 0.9662 - val_loss: 0.0592 - val_accuracy: 0.9873
# Epoch 6/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.0924 - accuracy: 0.9704 - val_loss: 0.4107 - val_accuracy: 0.8354
# Epoch 7/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.0398 - accuracy: 0.9873 - val_loss: 0.8002 - val_accuracy: 0.6835
# Epoch 8/100
# 23/23 [==============================] - 7s 302ms/step - loss: 0.0682 - accuracy: 0.9761 - val_loss: 0.3223 - val_accuracy: 0.8734
# Epoch 9/100
# 23/23 [==============================] - 7s 315ms/step - loss: 0.0612 - accuracy: 0.9775 - val_loss: 0.1134 - val_accuracy: 0.9367
# Epoch 10/100
# 23/23 [==============================] - 8s 320ms/step - loss: 0.0500 - accuracy: 0.9789 - val_loss: 0.0705 - val_accuracy: 0.9620
# Epoch 11/100
# 23/23 [==============================] - 7s 316ms/step - loss: 0.0428 - accuracy: 0.9887 - val_loss: 0.0769 - val_accuracy: 0.9620
# Epoch 12/100
# 23/23 [==============================] - 7s 316ms/step - loss: 0.0462 - accuracy: 0.9817 - val_loss: 0.0835 - val_accuracy: 0.9620
# Epoch 13/100
# 23/23 [==============================] - 8s 320ms/step - loss: 0.0757 - accuracy: 0.9789 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 14/100
# 23/23 [==============================] - 8s 327ms/step - loss: 0.0684 - accuracy: 0.9803 - val_loss: 0.0686 - val_accuracy: 0.9873
# Epoch 15/100
# 23/23 [==============================] - 7s 298ms/step - loss: 0.0686 - accuracy: 0.9761 - val_loss: 0.1872 - val_accuracy: 0.9367
# 3/3 [==============================] - 0s 39ms/step
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1872 - accuracy: 0.9367
# Epoch 1/100
# 23/23 [==============================] - 8s 318ms/step - loss: 0.0875 - accuracy: 0.9775 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 2/100
# 23/23 [==============================] - 7s 306ms/step - loss: 0.0651 - accuracy: 0.9803 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 3/100
# 23/23 [==============================] - 7s 306ms/step - loss: 0.1099 - accuracy: 0.9690 - val_loss: 0.0196 - val_accuracy: 0.9873
# Epoch 4/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.0593 - accuracy: 0.9718 - val_loss: 0.1026 - val_accuracy: 0.9494
# Epoch 5/100
# 23/23 [==============================] - 7s 311ms/step - loss: 0.0566 - accuracy: 0.9775 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 6/100
# 23/23 [==============================] - 7s 316ms/step - loss: 0.0744 - accuracy: 0.9718 - val_loss: 0.0292 - val_accuracy: 0.9873
# Epoch 7/100
# 23/23 [==============================] - 7s 300ms/step - loss: 0.0782 - accuracy: 0.9718 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 8/100
# 23/23 [==============================] - 7s 298ms/step - loss: 0.0840 - accuracy: 0.9662 - val_loss: 0.0143 - val_accuracy: 0.9873
# Epoch 9/100
# 23/23 [==============================] - 7s 295ms/step - loss: 0.0513 - accuracy: 0.9845 - val_loss: 0.0209 - val_accuracy: 0.9873
# Epoch 10/100
# 23/23 [==============================] - 7s 310ms/step - loss: 0.0809 - accuracy: 0.9803 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 11/100
# 23/23 [==============================] - 7s 309ms/step - loss: 0.0914 - accuracy: 0.9704 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 12/100
# 23/23 [==============================] - 7s 304ms/step - loss: 0.1009 - accuracy: 0.9577 - val_loss: 0.0280 - val_accuracy: 1.0000
# Epoch 13/100
# 23/23 [==============================] - 7s 296ms/step - loss: 0.1182 - accuracy: 0.9662 - val_loss: 0.3772 - val_accuracy: 0.8861
# Epoch 14/100
# 23/23 [==============================] - 7s 295ms/step - loss: 0.0667 - accuracy: 0.9732 - val_loss: 1.1335 - val_accuracy: 0.7595
# Epoch 15/100
# 23/23 [==============================] - 7s 304ms/step - loss: 0.0875 - accuracy: 0.9676 - val_loss: 1.1789 - val_accuracy: 0.7342
# Epoch 16/100
# 23/23 [==============================] - 7s 304ms/step - loss: 0.0793 - accuracy: 0.9690 - val_loss: 0.0435 - val_accuracy: 0.9620
# Epoch 17/100
# 23/23 [==============================] - 7s 294ms/step - loss: 0.0746 - accuracy: 0.9761 - val_loss: 0.0092 - val_accuracy: 1.0000
# 3/3 [==============================] - 0s 39ms/step
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 1/100
# 23/23 [==============================] - 7s 310ms/step - loss: 0.1022 - accuracy: 0.9662 - val_loss: 0.1779 - val_accuracy: 0.9367
# Epoch 2/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.1472 - accuracy: 0.9634 - val_loss: 0.1668 - val_accuracy: 0.9241
# Epoch 3/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.0546 - accuracy: 0.9775 - val_loss: 0.2124 - val_accuracy: 0.9114
# Epoch 4/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.0777 - accuracy: 0.9761 - val_loss: 0.0576 - val_accuracy: 0.9747
# Epoch 5/100
# 23/23 [==============================] - 7s 292ms/step - loss: 0.0835 - accuracy: 0.9732 - val_loss: 0.3724 - val_accuracy: 0.8608
# Epoch 6/100
# 23/23 [==============================] - 7s 307ms/step - loss: 0.0410 - accuracy: 0.9831 - val_loss: 0.2598 - val_accuracy: 0.8861
# Epoch 7/100
# 23/23 [==============================] - 7s 307ms/step - loss: 0.0771 - accuracy: 0.9746 - val_loss: 0.2637 - val_accuracy: 0.9114
# Epoch 8/100
# 23/23 [==============================] - 7s 310ms/step - loss: 0.0968 - accuracy: 0.9620 - val_loss: 0.1142 - val_accuracy: 0.9494
# Epoch 9/100
# 23/23 [==============================] - 7s 309ms/step - loss: 0.1254 - accuracy: 0.9507 - val_loss: 0.6484 - val_accuracy: 0.7342
# Epoch 10/100
# 23/23 [==============================] - 7s 296ms/step - loss: 0.1705 - accuracy: 0.9521 - val_loss: 1.4238 - val_accuracy: 0.6076
# Epoch 11/100
# 23/23 [==============================] - 7s 296ms/step - loss: 0.0951 - accuracy: 0.9620 - val_loss: 0.5424 - val_accuracy: 0.7848
# Epoch 12/100
# 23/23 [==============================] - 7s 298ms/step - loss: 0.0658 - accuracy: 0.9803 - val_loss: 0.1650 - val_accuracy: 0.9494
# Epoch 13/100
# 23/23 [==============================] - 7s 293ms/step - loss: 0.0720 - accuracy: 0.9803 - val_loss: 0.0686 - val_accuracy: 0.9620
# Epoch 14/100
# 23/23 [==============================] - 7s 299ms/step - loss: 0.0627 - accuracy: 0.9817 - val_loss: 0.1289 - val_accuracy: 0.9620
# 3/3 [==============================] - 0s 40ms/step
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1289 - accuracy: 0.9620
# Epoch 1/100
# 23/23 [==============================] - 7s 324ms/step - loss: 0.0607 - accuracy: 0.9803 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 2/100
# 23/23 [==============================] - 7s 304ms/step - loss: 0.0621 - accuracy: 0.9803 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 3/100
# 23/23 [==============================] - 7s 313ms/step - loss: 0.0429 - accuracy: 0.9803 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 4/100
# 23/23 [==============================] - 7s 314ms/step - loss: 0.0588 - accuracy: 0.9789 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 5/100
# 23/23 [==============================] - 7s 311ms/step - loss: 0.0436 - accuracy: 0.9831 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 6/100
# 23/23 [==============================] - 7s 302ms/step - loss: 0.0503 - accuracy: 0.9789 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 7/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.0511 - accuracy: 0.9859 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 8/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.0381 - accuracy: 0.9873 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 9/100
# 23/23 [==============================] - 7s 293ms/step - loss: 0.0316 - accuracy: 0.9859 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 10/100
# 23/23 [==============================] - 7s 297ms/step - loss: 0.0283 - accuracy: 0.9901 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 11/100
# 23/23 [==============================] - 7s 292ms/step - loss: 0.0655 - accuracy: 0.9761 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 12/100
# 23/23 [==============================] - 7s 299ms/step - loss: 0.0627 - accuracy: 0.9817 - val_loss: 3.8046e-04 - val_accuracy: 1.0000
# Epoch 13/100
# 23/23 [==============================] - 8s 321ms/step - loss: 0.0488 - accuracy: 0.9817 - val_loss: 0.0624 - val_accuracy: 0.9620
# Epoch 14/100
# 23/23 [==============================] - 7s 308ms/step - loss: 0.0351 - accuracy: 0.9845 - val_loss: 0.2395 - val_accuracy: 0.9241
# Epoch 15/100
# 23/23 [==============================] - 7s 313ms/step - loss: 0.0327 - accuracy: 0.9887 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 16/100
# 23/23 [==============================] - 7s 309ms/step - loss: 0.0442 - accuracy: 0.9831 - val_loss: 0.0309 - val_accuracy: 0.9873
# Epoch 17/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.1092 - accuracy: 0.9690 - val_loss: 0.8206 - val_accuracy: 0.8354
# Epoch 18/100
# 23/23 [==============================] - 7s 304ms/step - loss: 0.1536 - accuracy: 0.9662 - val_loss: 0.3334 - val_accuracy: 0.8734
# 3/3 [==============================] - 0s 39ms/step
# 3/3 [==============================] - 0s 33ms/step - loss: 0.3334 - accuracy: 0.8734
# Epoch 1/100
# 23/23 [==============================] - 7s 311ms/step - loss: 0.1121 - accuracy: 0.9732 - val_loss: 0.0231 - val_accuracy: 0.9873
# Epoch 2/100
# 23/23 [==============================] - 7s 299ms/step - loss: 0.0738 - accuracy: 0.9732 - val_loss: 0.0160 - val_accuracy: 0.9873
# Epoch 3/100
# 23/23 [==============================] - 7s 314ms/step - loss: 0.0549 - accuracy: 0.9845 - val_loss: 0.1043 - val_accuracy: 0.9367
# Epoch 4/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.0445 - accuracy: 0.9817 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 5/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.0482 - accuracy: 0.9831 - val_loss: 0.0993 - val_accuracy: 0.9620
# Epoch 6/100
# 23/23 [==============================] - 7s 295ms/step - loss: 0.0669 - accuracy: 0.9817 - val_loss: 0.0326 - val_accuracy: 1.0000
# Epoch 7/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.0487 - accuracy: 0.9845 - val_loss: 0.0298 - val_accuracy: 0.9873
# Epoch 8/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.0740 - accuracy: 0.9718 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 9/100
# 23/23 [==============================] - 7s 287ms/step - loss: 0.0704 - accuracy: 0.9746 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 10/100
# 23/23 [==============================] - 7s 294ms/step - loss: 0.0498 - accuracy: 0.9803 - val_loss: 0.0390 - val_accuracy: 1.0000
# Epoch 11/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.0551 - accuracy: 0.9817 - val_loss: 0.0450 - val_accuracy: 0.9873
# Epoch 12/100
# 23/23 [==============================] - 7s 296ms/step - loss: 0.0517 - accuracy: 0.9789 - val_loss: 0.0827 - val_accuracy: 0.9494
# 3/3 [==============================] - 0s 39ms/step
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0827 - accuracy: 0.9494
# Epoch 1/100
# 23/23 [==============================] - 9s 359ms/step - loss: 0.0357 - accuracy: 0.9859 - val_loss: 0.0165 - val_accuracy: 0.9872
# Epoch 2/100
# 23/23 [==============================] - 7s 292ms/step - loss: 0.0444 - accuracy: 0.9859 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 3/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.0416 - accuracy: 0.9845 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 4/100
# 23/23 [==============================] - 7s 300ms/step - loss: 0.0436 - accuracy: 0.9845 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 5/100
# 23/23 [==============================] - 7s 294ms/step - loss: 0.0652 - accuracy: 0.9817 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 6/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.0636 - accuracy: 0.9831 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 7/100
# 23/23 [==============================] - 7s 299ms/step - loss: 0.0345 - accuracy: 0.9887 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 8/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.0492 - accuracy: 0.9831 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 9/100
# 23/23 [==============================] - 7s 302ms/step - loss: 0.0464 - accuracy: 0.9775 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 10/100
# 23/23 [==============================] - 7s 302ms/step - loss: 0.0563 - accuracy: 0.9831 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 11/100
# 23/23 [==============================] - 7s 302ms/step - loss: 0.0630 - accuracy: 0.9761 - val_loss: 0.0253 - val_accuracy: 0.9872
# Epoch 12/100
# 23/23 [==============================] - 7s 304ms/step - loss: 0.0941 - accuracy: 0.9761 - val_loss: 0.0242 - val_accuracy: 0.9872
# Epoch 13/100
# 23/23 [==============================] - 7s 303ms/step - loss: 0.0435 - accuracy: 0.9831 - val_loss: 0.0306 - val_accuracy: 0.9872
# Epoch 14/100
# 23/23 [==============================] - 7s 316ms/step - loss: 0.0453 - accuracy: 0.9859 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 15/100
# 23/23 [==============================] - 8s 327ms/step - loss: 0.0239 - accuracy: 0.9873 - val_loss: 0.0285 - val_accuracy: 0.9872
# Epoch 16/100
# 23/23 [==============================] - 7s 300ms/step - loss: 0.0128 - accuracy: 0.9958 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 17/100
# 23/23 [==============================] - 7s 302ms/step - loss: 0.0296 - accuracy: 0.9916 - val_loss: 0.0118 - val_accuracy: 0.9872
# Epoch 18/100
# 23/23 [==============================] - 7s 295ms/step - loss: 0.0317 - accuracy: 0.9873 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 19/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.0284 - accuracy: 0.9930 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 20/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.0320 - accuracy: 0.9873 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 21/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.0308 - accuracy: 0.9916 - val_loss: 0.0184 - val_accuracy: 0.9872
# Epoch 22/100
# 23/23 [==============================] - 7s 287ms/step - loss: 0.0526 - accuracy: 0.9916 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 23/100
# 23/23 [==============================] - 7s 294ms/step - loss: 0.0539 - accuracy: 0.9859 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 24/100
# 23/23 [==============================] - 7s 295ms/step - loss: 0.0267 - accuracy: 0.9887 - val_loss: 0.0052 - val_accuracy: 1.0000
# 3/3 [==============================] - 0s 82ms/step
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0052 - accuracy: 1.0000
# [0.949367105960846, 0.9367088675498962, 0.9620253443717957, 1.0, 0.9367088675498962, 1.0, 0.9620253443717957, 0.8734177350997925, 0.949367105960846, 1.0] [0.17636944353580475, 0.1234917864203453, 0.12235627323389053, 0.009179911576211452, 0.18722181022167206, 0.009161360561847687, 0.1289156973361969, 0.33336564898490906, 0.08265887200832367, 0.005200027953833342]

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train','val'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model_custom.evaluate(X_Test,Y_Test)
# Out:
# 3/3 [==============================] - 1s 105ms/step - loss: 0.0052 - accuracy: 1.0000
# [0.005200027953833342, 1.0]

# %% [markdown]
# # 이미지 인덱싱으로 지정하여 예측

# %%
preds= model_custom.predict(X_Test[1:2])
preds
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[5.8366801e-05, 9.9993777e-01, 3.8224812e-06, 1.3176533e-12]],
#       dtype=float32)

# %%
plt.imshow(X_Test[1:2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [163], line 1
# ----> 1 plt.imshow(X_Test[1:2])
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/pyplot.py:2611, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2605 @_copy_docstring_and_deprecators(Axes.imshow)
#    2606 def imshow(
#    2607         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    2608         alpha=None, vmin=None, vmax=None, origin=None, extent=None, *,
#    2609         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2610         resample=None, url=None, data=None, **kwargs):
# -> 2611     __ret = gca().imshow(
#    2612         X, cmap=cmap, norm=norm, aspect=aspect,
#    2613         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2614         vmax=vmax, origin=origin, extent=extent,
#    2615         interpolation_stage=interpolation_stage,
#    2616         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2617         url=url, **({"data": data} if data is not None else {}),
#    2618         **kwargs)
#    2619     sci(__ret)
#    2620     return __ret
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5572, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5564 self.set_aspect(aspect)
#    5565 im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    5566                       interpolation=interpolation, origin=origin,
#    5567                       extent=extent, filternorm=filternorm,
#    5568                       filterrad=filterrad, resample=resample,
#    5569                       interpolation_stage=interpolation_stage,
#    5570                       **kwargs)
# -> 5572 im.set_data(X)
#    5573 im.set_alpha(alpha)
#    5574 if im.get_clip_path() is None:
#    5575     # image does not already have clipping set, clip to axes patch
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/image.py:710, in _ImageBase.set_data(self, A)
#     706     self._A = self._A[:, :, 0]
#     708 if not (self._A.ndim == 2
#     709         or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 710     raise TypeError("Invalid shape {} for image data"
#     711                     .format(self._A.shape))
#     713 if self._A.ndim == 3:
#     714     # If the input data has values outside the valid range (after
#     715     # normalisation), we issue a warning and then clip X to the bounds
#     716     # - otherwise casting wraps extreme values, hiding outliers and
#     717     # making reliable interpretation impossible.
#     718     high = 255 if np.issubdtype(self._A.dtype, np.integer) else 1
#
# TypeError: Invalid shape (1, 300, 300, 3) for image data

# %% [markdown]
# # 이미지 경로로 지정하여 예측

# %%
# surprise
# img = cv2.imread('./Input/CK+48/surprise/croped_image190.jpg')
# img = cv2.imread('./Input/CK+48/surprise/croped_image76.jpg')
#sadness #얘는 구분됨.
img = cv2.imread('./Input/CK+48/sadness/croped_image456.jpg')
# img = cv2.imread('./Input/CK+48/sadness/croped_image418.jpg')
#happy
# img = cv2.imread('./Input/CK+48/happy/croped_image38.jpg')
# img = cv2.imread('./Input/CK+48/happy/S010_006_00000013.png')

#anger
# img = cv2.imread('./Input/CK+48/anger/croped_image114.jpg')
# img =cv2.resize(img,(300,300),interpolation=cv2.INTER_LINEAR)
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
preds= model_custom.predict(img.reshape(-1,300,300,3))
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# preds = model_custom.predict(cv2.resize(img_list[0:1],(300,300),interpolation=cv2.INTER_LINEAR))
# img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
# img.reshape(-1,300,300,1)
# img.shape
preds
# Out:
# 1/1 [==============================] - 0s 16ms/step
# array([[0., 0., 0., 1.]], dtype=float32)

# %%
# img.shape
plt.imshow(img)
# plt.imshow(X_Test[0:1].reshape(300,300,3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [147], line 2
#       1 # img.shape
# ----> 2 plt.imshow(img)
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/pyplot.py:2611, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2605 @_copy_docstring_and_deprecators(Axes.imshow)
#    2606 def imshow(
#    2607         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    2608         alpha=None, vmin=None, vmax=None, origin=None, extent=None, *,
#    2609         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2610         resample=None, url=None, data=None, **kwargs):
# -> 2611     __ret = gca().imshow(
#    2612         X, cmap=cmap, norm=norm, aspect=aspect,
#    2613         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2614         vmax=vmax, origin=origin, extent=extent,
#    2615         interpolation_stage=interpolation_stage,
#    2616         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2617         url=url, **({"data": data} if data is not None else {}),
#    2618         **kwargs)
#    2619     sci(__ret)
#    2620     return __ret
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5572, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5564 self.set_aspect(aspect)
#    5565 im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    5566                       interpolation=interpolation, origin=origin,
#    5567                       extent=extent, filternorm=filternorm,
#    5568                       filterrad=filterrad, resample=resample,
#    5569                       interpolation_stage=interpolation_stage,
#    5570                       **kwargs)
# -> 5572 im.set_data(X)
#    5573 im.set_alpha(alpha)
#    5574 if im.get_clip_path() is None:
#    5575     # image does not already have clipping set, clip to axes patch
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/image.py:701, in _ImageBase.set_data(self, A)
#     697 self._A = cbook.safe_masked_invalid(A, copy=True)
#     699 if (self._A.dtype != np.uint8 and
#     700         not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 701     raise TypeError("Image data of dtype {} cannot be converted to "
#     702                     "float".format(self._A.dtype))
#     704 if self._A.ndim == 3 and self._A.shape[-1] == 1:
#     705     # If just one dimension assume scalar and apply colormap
#     706     self._A = self._A[:, :, 0]
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
plt.bar(range(1,5), preds[0])
plt.xlabel('class')
plt.ylabel('prob.')
plt.show()

# %%
def getLabel_Incoding(preds):
    index = np.argmax(preds)
    print(index)
    return names[index]

# %%
getLabel_Incoding(preds)
# Out:
# 0
# 'happy'

# %%
plt.imshow(X_Test[0:1].reshape(64,64,3))
cv2.resize(input_img,(300,300),interpolation=cv2.INTER_LINEAR)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [243], line 1
# ----> 1 plt.imshow(X_Test[0:1].reshape(64,64,3))
#
# ValueError: cannot reshape array of size 270000 into shape (64,64,3)

# %%
plt.imshow(x[1])

# %%
y[1]
# Out:
# array([0., 0., 0., 0., 1.], dtype=float32)

# %%
print(getLabel(y[2]))
# Out:
# surprise

# %%
Y[0]
# Out:
# array([1., 0., 0., 0.], dtype=float32)

# %%
from keras.models import load_model
emotion_detect_model = load_model('weights_best_emotion_detect3.h5')

# %%
emotion_detect_model.summary()
# Out:
# Model: "sequential_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_117 (Conv2D)         (None, 64, 64, 16)        208
#
#  max_pooling2d_112 (MaxPooli  (None, 32, 32, 16)       0
#  ng2D)
#
#  conv2d_118 (Conv2D)         (None, 32, 32, 32)        2080
#
#  max_pooling2d_113 (MaxPooli  (None, 16, 16, 32)       0
#  ng2D)
#
#  conv2d_119 (Conv2D)         (None, 16, 16, 32)        4128
#
#  max_pooling2d_114 (MaxPooli  (None, 8, 8, 32)         0
#  ng2D)
#
#  conv2d_120 (Conv2D)         (None, 8, 8, 64)          8256
#
#  max_pooling2d_115 (MaxPooli  (None, 4, 4, 64)         0
#  ng2D)
#
#  conv2d_121 (Conv2D)         (None, 4, 4, 128)         32896
#
#  max_pooling2d_116 (MaxPooli  (None, 2, 2, 128)        0
#  ng2D)
#
#  flatten_36 (Flatten)        (None, 512)               0
#
#  dense_73 (Dense)            (None, 256)               131328
#
#  dense_74 (Dense)            (None, 128)               32896
#
#  dropout_31 (Dropout)        (None, 128)               0
#
#  dense_75 (Dense)            (None, 7)                 903
#
# =================================================================
# Total params: 212,695
# Trainable params: 212,695
# Non-trainable params: 0
# _________________________________________________________________

# %%
img = cv2.imread('./image/croped_image19.jpg')
preds= emotion_detect_model.predict(img.reshape(-1,64,64,3))
text = getLabel_Incoding(preds)
print(text)
# preds= emotion_detect_model.predict()
# Out:
# 1/1 [==============================] - 0s 135ms/step
# contempt
# 2022-11-20 02:06:16.970052: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
print(getLabel(y[2]))
# Out:
# fear

# %%
#happy
# crop = img[10:290,10:290]
#sadness
# crop = img[660:940,1630:1910]
#anger
# crop = img[1000:1280,1630:1910]
#surprise
# crop = img[10:290,1630:1910]
#disgust
# crop = img[320:600,10:290]
#contempt
# crop = img[320:600,345:625]

#fear
crop = img[1000:1280,10:290]

a = 'fear'
dst = cv2.resize(crop, (300, 300), interpolation=cv2.INTER_LINEAR) 
cv2.imwrite(f'./emoticon/{a}.jpg', dst)
# Out:
# True

# %%
# Out:
# file list: ['happy', 'contempt', 'fear', 'surprise', 'sadness', 'anger', 'disgust']
# Loaded the images of dataset-happy
#
# Loaded the images of dataset-contempt
#
# Loaded the images of dataset-fear
#
# Loaded the images of dataset-surprise
#
# Loaded the images of dataset-sadness
#
# Loaded the images of dataset-anger
#
# Loaded the images of dataset-disgust
#
# (981, 48, 48, 3)
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_74 (Conv2D)          (None, 48, 48, 6)         456
#
#  max_pooling2d_70 (MaxPoolin  (None, 24, 24, 6)        0
#  g2D)
#
#  conv2d_75 (Conv2D)          (None, 24, 24, 16)        2416
#
#  activation_20 (Activation)  (None, 24, 24, 16)        0
#
#  max_pooling2d_71 (MaxPoolin  (None, 12, 12, 16)       0
#  g2D)
#
#  conv2d_76 (Conv2D)          (None, 10, 10, 64)        9280
#
#  max_pooling2d_72 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  flatten_24 (Flatten)        (None, 1600)              0
#
#  dense_48 (Dense)            (None, 128)               204928
#
#  dropout_20 (Dropout)        (None, 128)               0
#
#  dense_49 (Dense)            (None, 7)                 903
#
# =================================================================
# Total params: 217,983
# Trainable params: 217,983
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_77 (Conv2D)          (None, 46, 46, 64)        1792
#
#  max_pooling2d_73 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_78 (Conv2D)          (None, 13, 13, 128)       73856
#
#  conv2d_79 (Conv2D)          (None, 11, 11, 256)       295168
#
#  max_pooling2d_74 (MaxPoolin  (None, 3, 3, 256)        0
#  g2D)
#
#  flatten_25 (Flatten)        (None, 2304)              0
#
#  dense_50 (Dense)            (None, 256)               590080
#
#  dense_51 (Dense)            (None, 7)                 1799
#
# =================================================================
# Total params: 962,695
# Trainable params: 962,695
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2022-11-20 00:47:41.640063: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In [138], line 157
#     153 model.summary()
#     155 model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
# --> 157 history = model.fit(train_generator, batch_size=8 , epochs=20, validation_data = (X_test, y_test), callbacks = [callbacks],shuffle=True)
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits' defined at (most recent call last):
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/traitlets/config/application.py", line 978, in launch_instance
#       app.start()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#       self._run_once()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#       handle._run()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2885, in run_cell
#       result = self._run_cell(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#       return runner(coro)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3139, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3318, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3378, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/zh/v9f2b_v55ml9_yp9qr_69lk40000gn/T/ipykernel_7464/1755166853.py", line 157, in <module>
#       history = model.fit(train_generator, batch_size=8 , epochs=20, validation_data = (X_test, y_test), callbacks = [callbacks],shuffle=True)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 994, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1052, in compute_loss
#       return self.compiled_loss(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 152, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 272, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 2084, in sparse_categorical_crossentropy
#       return backend.sparse_categorical_crossentropy(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/backend.py", line 5630, in sparse_categorical_crossentropy
#       res = tf.nn.sparse_softmax_cross_entropy_with_logits(
# Node: 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits'
# Detected at node 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits' defined at (most recent call last):
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/traitlets/config/application.py", line 978, in launch_instance
#       app.start()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#       self._run_once()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#       handle._run()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2885, in run_cell
#       result = self._run_cell(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#       return runner(coro)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3139, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3318, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3378, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/zh/v9f2b_v55ml9_yp9qr_69lk40000gn/T/ipykernel_7464/1755166853.py", line 157, in <module>
#       history = model.fit(train_generator, batch_size=8 , epochs=20, validation_data = (X_test, y_test), callbacks = [callbacks],shuffle=True)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 994, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1052, in compute_loss
#       return self.compiled_loss(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 152, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 272, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 2084, in sparse_categorical_crossentropy
#       return backend.sparse_categorical_crossentropy(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/backend.py", line 5630, in sparse_categorical_crossentropy
#       res = tf.nn.sparse_softmax_cross_entropy_with_logits(
# Node: 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits'
# 2 root error(s) found.
#   (0) INVALID_ARGUMENT:  logits and labels must have the same first dimension, got logits shape [8,7] and labels shape [56]
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]]
# 	 [[Equal/_21]]
#   (1) INVALID_ARGUMENT:  logits and labels must have the same first dimension, got logits shape [8,7] and labels shape [56]
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_706677]

# %% [markdown]
# # 데이터셋의 이미지 크기 정보 알아오기

# %%
import os
import cv2
data_path = './Input/CK+48'
file_list = os.listdir(data_path)
# file_list.remove('./DS_Store')
print("file list:",file_list)

num_epoch=10

img_data_list=[]

data_dir_list = os.listdir(data_path)

#우리가 파일을 만든 순서가 아닌 컴퓨터가 지가 읽는 순서대로 파일을 불러옴.
for dataset in data_dir_list:
    if dataset in '.DS_Store':
            continue
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.        
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        print(input_img.shape)
#         input_img_resize=cv2.resize(input_img,(48,48))
#         img_data_list.append(input_img_resize)
# Out:
# file list: ['happy', '.DS_Store', 'contempt', 'fear', 'surprise', 'sadness', 'anger', 'disgust']
# Loaded the images of dataset-happy
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-contempt
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-fear
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-surprise
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-sadness
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-anger
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-disgust
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)

# %%
additional_data_path = './image'
additional_data_list = os.listdir(additional_data_path)
for dataset in additional_data_list:
    img_list=os.listdir(additional_data_path+'/'+ dataset)
#     print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.        
        input_img=cv2.imread(additional_data_path + '/'+ dataset + '/'+ img )
        
        print(input_img.shape)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In [4], line 4
#       2 additional_data_list = os.listdir(additional_data_path)
#       3 for dataset in additional_data_list:
# ----> 4     img_list=os.listdir(additional_data_path+'/'+ dataset)
#       5 #     print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
#       6     for img in img_list:
#       7         #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.
#
# NotADirectoryError: [Errno 20] Not a directory: './image/croped_image817.jpg'

# %%
def show_40sample_images(X_train, y_train):
    # 이 데이터셋에 있는 샘플 이미지를 몇 개 출력해 보죠:
    n_rows = 4
    n_cols = 10
    plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
    for row in range(n_rows):
        for col in range(n_cols):
            index = n_cols * row + col
            plt.subplot(n_rows, n_cols, index + 1)
            plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
            plt.axis('off')
            plt.title(class_names[int(y_train[index])], fontsize=12)
    plt.subplots_adjust(wspace=0.2, hspace=0.5)
    plt.show()

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os,cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#matplotlib을 통해 보여줄 그래프의 크기를 직접 지정해 준것.
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import tensorflow as tf

from keras.utils import np_utils
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
from keras.models import Sequential
from keras.layers import *
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
import os
data_path = './Input/CK+48'
file_list = os.listdir(data_path)
file_list.remove('.DS_Store')

print("file list:",file_list)

# Any results you write to the current directory are saved as output

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.datasets import make_classification
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

#디렉토리에서 이미지를 추출하기

num_epoch=10

img_data_list=[]

labels = []
labeled = 0
img_count = 0
#우리가 파일을 만든 순서가 아닌 컴퓨터가 지가 읽는 순서대로 파일을 불러옴.
for dataset in file_list:
    img_one_cat_len = 0
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.        
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        input_img_resize=cv2.resize(input_img,(300,300),interpolation=cv2.INTER_LINEAR)
#         input_img_gray = cv2.cvtColor(input_img_resize, cv2.COLOR_RGB2GRAY)
        img_data_list.append(input_img_resize)
        img_one_cat_len +=1
    #라벨링 넘파이 배열 생성 
    for label in range(img_one_cat_len):
        labels.append(labeled)

    labeled += 1

img_data = np.array(img_data_list)
labels = np.array(labels)

#이미지 데이터 정규화

img_data = img_data.astype('float32')
img_data = img_data/255 #normalization
print(img_data.shape)

num_classes = len(file_list)

# 카테고리 리스트로 선언
names = file_list

#라벨 이름 리턴
def getLabel(labels): 
    return names[labels.index(1)]
def getLabel_Incoding(preds):
    index = np.argmax(preds)
    return names[index-1]    

# 훈련, 검증 데이터 셋 분리.

#원핫 인코딩 /  (파라미터 값, 0으로된 배열의 크기)
# 0: 1000000
# 1: 0100000
# 2: 0010000
#하나의 이미지에 대해 0과 1로 라벨링된(원핫인코딩된)배열을 리턴받음.
Y = np_utils.to_categorical(labels, num_classes)

#Shuffle the dataset
x,y = shuffle(img_data,Y, random_state=2)
# Split the dataset
# X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

#모델 생성 및 요약

from keras.models import load_model
model_custom = load_model('weights_best_emotion_detect5.h5')

model_custom.summary()

#Conduct k-Fold Cross-validation

from sklearn.model_selection import KFold

# kfold 교차 검증
# 데이터가 적은 데이터 셋에 대하여 정확도를 향상 시키기 위함.
# 이는 기존에 Training / Validation / Test 세개의 집단으로 분류하는것 보다 Training / Test로만 분류할때 학습 데이터 셋이 더 많기 때문.

# 5개의 폴드 세트로 분리하는 K Fold 객체와 폴드 세트별 정확도를 담을 리스트 객체 생성.
kf = KFold(n_splits=10, shuffle=False)

#Data Augmentation 기능 / 데이터 증강 기법
#모델의 성능을 높이면서 오버피팅을 극복하기 위해 학습 데이터의 다양성을 늘리기 위함.
#하나의 원본 이미지를 다양항 버전으로 만들어 학습시키는 것.
#대표적인 데이터 증강 기법으로는 원본 이미지를 수평 또는 수직 반전 시키는 방법, 회전시키는 방법, 일부를 자르는 방법,RGB채널 순서를 바꾸거나 
#픽셀값을 변경하여 원본 이미지의 색조를 변경시키는 것들이 있음.
#이러한 이미지 증강 기법을 tf.keras의 ImageDataGenerator 가 대신해줌.
#이 툴 이외에 Data Albumenation이나, ImgAug, Tensorflow Image Library 등 다양한 데이터 증강 기법 툴들이 있음.

from keras.preprocessing.image import ImageDataGenerator

# 이미지 증강법 1단계.ImageDataGenerator 객체(aug)를 생성하면서 증강을 수행할 유형들을 지정.
aug = ImageDataGenerator(
    rotation_range = 40,
    zoom_range = 0.2,
    horizontal_flip = True,
    fill_mode = 'nearest')

#Training Model 
BS = 8 # batch size
EPOCHS = 100 # epochs

result = []
scores_loss = []
scores_acc = []
k_no = 0

#Kfold 객체의 split()을 호출하면 폴드별 학습용, 검증용 테스트의 로우 인덱스를 array로 반환
#split()이 알아서 학습용 검증용 데이터를 나누어줌. 위에서 k=5라고 지정한 경우 for문이 5번 돌아 가면서 학습용, 검증용 데이터를 나누어 줌.
for train_index, test_index in kf.split(x):
    #Kfold 객채의 split()으로 반환된 인덱스를 이용해 학습용, 검증용 테스트 데이터를 추출함.
    X_Train,X_Test = x[train_index], x[test_index]
    Y_Train,Y_Test = y[train_index], y[test_index]

    # 최적의 모델을 저장할 경로
    file_path = "./weights_best_emotion_detect4.h5"
    # 콜백 함수. (체크포인트, 조기 종료 선언)
    checkpoint = ModelCheckpoint(file_path, monitor='loss', save_best_only=True, mode='min')
    early = EarlyStopping(monitor="loss", mode="min", patience=8)

    callbacks_list = [checkpoint, early]

    #이미지 증강법 2단계 aug.flow(X,y,batch_size=,shuffle=) : X(훈련 이미지),y(라벨), 이미지를 한번에 몇개 업로드 시킬지에 대한 배치 사이즈,데이터 셔플 유무
    #flow 메소드로 생성한 객체는 Numpy Array Iterator 객체로 우리가 흔히 아는 Python Iterator처럼 loop문이나 next()함수를 사용해 Iterator 안에 데이터를 하나씩 호출 가능.

    hist = model_custom.fit_generator(aug.flow(X_Train, Y_Train), epochs=EPOCHS,validation_data=(X_Test, Y_Test), callbacks=callbacks_list)
    # model.fit(X_Train, Y_Train, batch_size=batch_size, epochs=epochs, validation_data=(X_Test, Y_Test), verbose=1)
    
#     model_custom.load_weights(file_path)
    result.append(model_custom.predict(X_Test))
    score = model_custom.evaluate(X_Test,Y_Test)
    scores_loss.append(score[0])
    scores_acc.append(score[1])
    k_no+=1

print(scores_acc,scores_loss)
# Out:
# file list: ['happy', 'surprise', 'sadness', 'anger']
# Loaded the images of dataset-happy
#
# Loaded the images of dataset-surprise
#
# Loaded the images of dataset-sadness
#
# Loaded the images of dataset-anger
#
# (792, 300, 300, 3)
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_28 (Conv2D)          (None, 300, 300, 32)      896
#
#  batch_normalization_28 (Bat  (None, 300, 300, 32)     128
#  chNormalization)
#
#  max_pooling2d_28 (MaxPoolin  (None, 150, 150, 32)     0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 150, 150, 64)      18496
#
#  batch_normalization_29 (Bat  (None, 150, 150, 64)     256
#  chNormalization)
#
#  max_pooling2d_29 (MaxPoolin  (None, 75, 75, 64)       0
#  g2D)
#
#  conv2d_30 (Conv2D)          (None, 75, 75, 32)        18464
#
#  batch_normalization_30 (Bat  (None, 75, 75, 32)       128
#  chNormalization)
#
#  max_pooling2d_30 (MaxPoolin  (None, 37, 37, 32)       0
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 37, 37, 16)        4624
#
#  batch_normalization_31 (Bat  (None, 37, 37, 16)       64
#  chNormalization)
#
#  max_pooling2d_31 (MaxPoolin  (None, 18, 18, 16)       0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 5184)              0
#
#  dense_12 (Dense)            (None, 256)               1327360
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 4)                 1028
#
# =================================================================
# Total params: 1,371,444
# Trainable params: 1,371,156
# Non-trainable params: 288
# _________________________________________________________________
# /var/folders/zh/v9f2b_v55ml9_yp9qr_69lk40000gn/T/ipykernel_94752/3873763211.py:163: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model_custom.fit_generator(aug.flow(X_Train, Y_Train), epochs=EPOCHS,validation_data=(X_Test, Y_Test), callbacks=callbacks_list)
# Epoch 1/100
# 2022-11-28 16:00:30.196967: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 23/23 [==============================] - ETA: 0s - loss: 0.2362 - accuracy: 0.9508
# 2022-11-28 16:00:39.486860: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 23/23 [==============================] - 10s 369ms/step - loss: 0.2362 - accuracy: 0.9508 - val_loss: 1.6029 - val_accuracy: 0.8750
# Epoch 2/100
# 23/23 [==============================] - 7s 293ms/step - loss: 0.2208 - accuracy: 0.9480 - val_loss: 1.1481 - val_accuracy: 0.7875
# Epoch 3/100
# 23/23 [==============================] - 7s 294ms/step - loss: 0.1593 - accuracy: 0.9382 - val_loss: 0.0874 - val_accuracy: 0.9750
# Epoch 4/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.1490 - accuracy: 0.9410 - val_loss: 0.0265 - val_accuracy: 0.9875
# Epoch 5/100
# 23/23 [==============================] - 7s 299ms/step - loss: 0.1226 - accuracy: 0.9522 - val_loss: 0.1053 - val_accuracy: 0.9750
# Epoch 6/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.1568 - accuracy: 0.9466 - val_loss: 0.7643 - val_accuracy: 0.8000
# Epoch 7/100
# 23/23 [==============================] - 7s 298ms/step - loss: 0.1450 - accuracy: 0.9480 - val_loss: 2.1368 - val_accuracy: 0.5750
# Epoch 8/100
# 23/23 [==============================] - 7s 295ms/step - loss: 0.1447 - accuracy: 0.9621 - val_loss: 0.3629 - val_accuracy: 0.8500
# Epoch 9/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.1357 - accuracy: 0.9494 - val_loss: 0.4958 - val_accuracy: 0.8500
# Epoch 10/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.0976 - accuracy: 0.9635 - val_loss: 0.1186 - val_accuracy: 0.9625
# Epoch 11/100
# 23/23 [==============================] - 7s 300ms/step - loss: 0.0564 - accuracy: 0.9789 - val_loss: 0.1240 - val_accuracy: 0.9625
# Epoch 12/100
# 23/23 [==============================] - 7s 293ms/step - loss: 0.0996 - accuracy: 0.9677 - val_loss: 0.0601 - val_accuracy: 0.9875
# Epoch 13/100
# 23/23 [==============================] - 7s 285ms/step - loss: 0.1128 - accuracy: 0.9621 - val_loss: 0.4559 - val_accuracy: 0.8750
# Epoch 14/100
# 23/23 [==============================] - 7s 285ms/step - loss: 0.0989 - accuracy: 0.9579 - val_loss: 0.6927 - val_accuracy: 0.8750
# Epoch 15/100
# 23/23 [==============================] - 7s 297ms/step - loss: 0.0769 - accuracy: 0.9677 - val_loss: 0.3925 - val_accuracy: 0.8125
# Epoch 16/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.0713 - accuracy: 0.9705 - val_loss: 0.1217 - val_accuracy: 0.9250
# Epoch 17/100
# 23/23 [==============================] - 7s 285ms/step - loss: 0.0953 - accuracy: 0.9649 - val_loss: 0.3013 - val_accuracy: 0.9125
# Epoch 18/100
# 23/23 [==============================] - 7s 285ms/step - loss: 0.0967 - accuracy: 0.9677 - val_loss: 0.2332 - val_accuracy: 0.9250
# Epoch 19/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.1067 - accuracy: 0.9635 - val_loss: 0.0548 - val_accuracy: 0.9875
# 3/3 [==============================] - 0s 50ms/step
# 2022-11-28 16:02:43.132283: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0548 - accuracy: 0.9875
# Epoch 1/100
# 23/23 [==============================] - 7s 304ms/step - loss: 0.0699 - accuracy: 0.9775 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 2/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.1027 - accuracy: 0.9663 - val_loss: 0.0270 - val_accuracy: 0.9875
# Epoch 3/100
# 23/23 [==============================] - 7s 294ms/step - loss: 0.0983 - accuracy: 0.9607 - val_loss: 0.1586 - val_accuracy: 0.9500
# Epoch 4/100
# 23/23 [==============================] - 7s 294ms/step - loss: 0.0430 - accuracy: 0.9860 - val_loss: 0.0383 - val_accuracy: 0.9875
# Epoch 5/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.0609 - accuracy: 0.9775 - val_loss: 0.0364 - val_accuracy: 0.9875
# Epoch 6/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.0678 - accuracy: 0.9719 - val_loss: 0.0428 - val_accuracy: 0.9875
# Epoch 7/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.0556 - accuracy: 0.9775 - val_loss: 0.0409 - val_accuracy: 0.9875
# Epoch 8/100
# 23/23 [==============================] - 7s 294ms/step - loss: 0.0276 - accuracy: 0.9902 - val_loss: 1.6071 - val_accuracy: 0.7875
# Epoch 9/100
# 23/23 [==============================] - 7s 305ms/step - loss: 0.0345 - accuracy: 0.9888 - val_loss: 0.1224 - val_accuracy: 0.9500
# Epoch 10/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.0326 - accuracy: 0.9916 - val_loss: 0.0738 - val_accuracy: 0.9750
# Epoch 11/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.0312 - accuracy: 0.9916 - val_loss: 0.0443 - val_accuracy: 0.9750
# Epoch 12/100
# 23/23 [==============================] - 7s 285ms/step - loss: 0.0308 - accuracy: 0.9874 - val_loss: 0.1857 - val_accuracy: 0.9125
# Epoch 13/100
# 23/23 [==============================] - 7s 281ms/step - loss: 0.0904 - accuracy: 0.9761 - val_loss: 0.0872 - val_accuracy: 0.9750
# Epoch 14/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.0916 - accuracy: 0.9677 - val_loss: 0.0898 - val_accuracy: 0.9625
# Epoch 15/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.0753 - accuracy: 0.9719 - val_loss: 0.0514 - val_accuracy: 0.9750
# Epoch 16/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.0504 - accuracy: 0.9803 - val_loss: 0.0625 - val_accuracy: 0.9750
# 3/3 [==============================] - 0s 32ms/step
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0625 - accuracy: 0.9750
# Epoch 1/100
# 23/23 [==============================] - 8s 327ms/step - loss: 0.0487 - accuracy: 0.9860 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 2/100
# 23/23 [==============================] - 7s 299ms/step - loss: 0.0481 - accuracy: 0.9790 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 3/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.0366 - accuracy: 0.9846 - val_loss: 0.0644 - val_accuracy: 0.9747
# Epoch 4/100
# 23/23 [==============================] - 7s 298ms/step - loss: 0.0520 - accuracy: 0.9888 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 5/100
# 23/23 [==============================] - 7s 295ms/step - loss: 0.0514 - accuracy: 0.9860 - val_loss: 0.0290 - val_accuracy: 0.9873
# Epoch 6/100
# 23/23 [==============================] - 7s 296ms/step - loss: 0.0705 - accuracy: 0.9776 - val_loss: 0.3588 - val_accuracy: 0.8734
# Epoch 7/100
# 23/23 [==============================] - 7s 306ms/step - loss: 0.0433 - accuracy: 0.9888 - val_loss: 2.5504 - val_accuracy: 0.7848
# Epoch 8/100
# 23/23 [==============================] - 7s 304ms/step - loss: 0.0369 - accuracy: 0.9888 - val_loss: 0.1049 - val_accuracy: 0.9620
# Epoch 9/100
# 23/23 [==============================] - 7s 307ms/step - loss: 0.0858 - accuracy: 0.9734 - val_loss: 0.3354 - val_accuracy: 0.8734
# Epoch 10/100
# 23/23 [==============================] - 7s 311ms/step - loss: 0.0542 - accuracy: 0.9776 - val_loss: 0.8767 - val_accuracy: 0.8481
# Epoch 11/100
# 23/23 [==============================] - 7s 323ms/step - loss: 0.0412 - accuracy: 0.9832 - val_loss: 0.0234 - val_accuracy: 1.0000
# 3/3 [==============================] - 0s 61ms/step
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 1/100
# 23/23 [==============================] - 8s 326ms/step - loss: 0.0559 - accuracy: 0.9776 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 2/100
# 23/23 [==============================] - 7s 313ms/step - loss: 0.0400 - accuracy: 0.9902 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 3/100
# 23/23 [==============================] - 7s 310ms/step - loss: 0.0470 - accuracy: 0.9874 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 4/100
# 23/23 [==============================] - 7s 310ms/step - loss: 0.0399 - accuracy: 0.9860 - val_loss: 1.1968 - val_accuracy: 0.7722
# Epoch 5/100
# 23/23 [==============================] - 7s 313ms/step - loss: 0.0845 - accuracy: 0.9762 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 6/100
# 23/23 [==============================] - 7s 318ms/step - loss: 0.1106 - accuracy: 0.9734 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 7/100
# 23/23 [==============================] - 7s 306ms/step - loss: 0.0784 - accuracy: 0.9762 - val_loss: 0.0883 - val_accuracy: 0.9367
# Epoch 8/100
# 23/23 [==============================] - 7s 308ms/step - loss: 0.0648 - accuracy: 0.9790 - val_loss: 0.1667 - val_accuracy: 0.9241
# Epoch 9/100
# 23/23 [==============================] - 7s 302ms/step - loss: 0.0621 - accuracy: 0.9748 - val_loss: 0.0679 - val_accuracy: 0.9873
# Epoch 10/100
# 23/23 [==============================] - 7s 293ms/step - loss: 0.0496 - accuracy: 0.9804 - val_loss: 2.8024 - val_accuracy: 0.7595
# Epoch 11/100
# 23/23 [==============================] - 7s 311ms/step - loss: 0.0638 - accuracy: 0.9804 - val_loss: 0.1047 - val_accuracy: 0.9620
# Epoch 12/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.0693 - accuracy: 0.9776 - val_loss: 0.0177 - val_accuracy: 1.0000
# 3/3 [==============================] - 0s 38ms/step
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 1/100
# 23/23 [==============================] - 7s 313ms/step - loss: 0.0851 - accuracy: 0.9734 - val_loss: 0.0298 - val_accuracy: 0.9873
# Epoch 2/100
# 23/23 [==============================] - 7s 294ms/step - loss: 0.0698 - accuracy: 0.9719 - val_loss: 0.0357 - val_accuracy: 0.9747
# Epoch 3/100
# 23/23 [==============================] - 7s 317ms/step - loss: 0.0585 - accuracy: 0.9762 - val_loss: 0.0830 - val_accuracy: 0.9620
# Epoch 4/100
# 23/23 [==============================] - 7s 298ms/step - loss: 0.0700 - accuracy: 0.9762 - val_loss: 1.0643 - val_accuracy: 0.8608
# Epoch 5/100
# 23/23 [==============================] - 7s 292ms/step - loss: 0.0551 - accuracy: 0.9804 - val_loss: 0.0162 - val_accuracy: 0.9873
# Epoch 6/100
# 23/23 [==============================] - 7s 313ms/step - loss: 0.0537 - accuracy: 0.9790 - val_loss: 0.3601 - val_accuracy: 0.8861
# Epoch 7/100
# 23/23 [==============================] - 7s 316ms/step - loss: 0.0466 - accuracy: 0.9818 - val_loss: 0.0158 - val_accuracy: 0.9873
# Epoch 8/100
# 23/23 [==============================] - 8s 335ms/step - loss: 0.0404 - accuracy: 0.9874 - val_loss: 0.0323 - val_accuracy: 0.9873
# Epoch 9/100
# 23/23 [==============================] - 7s 311ms/step - loss: 0.0270 - accuracy: 0.9860 - val_loss: 0.1329 - val_accuracy: 0.9114
# Epoch 10/100
# 23/23 [==============================] - 8s 321ms/step - loss: 0.0452 - accuracy: 0.9818 - val_loss: 0.0374 - val_accuracy: 0.9873
# Epoch 11/100
# 23/23 [==============================] - 7s 299ms/step - loss: 0.0682 - accuracy: 0.9916 - val_loss: 0.2918 - val_accuracy: 0.9114
# Epoch 12/100
# 23/23 [==============================] - 7s 315ms/step - loss: 0.0686 - accuracy: 0.9874 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 13/100
# 23/23 [==============================] - 7s 295ms/step - loss: 0.0336 - accuracy: 0.9832 - val_loss: 0.0391 - val_accuracy: 0.9747
# Epoch 14/100
# 23/23 [==============================] - 7s 315ms/step - loss: 0.0482 - accuracy: 0.9846 - val_loss: 0.1129 - val_accuracy: 0.9620
# Epoch 15/100
# 23/23 [==============================] - 8s 319ms/step - loss: 0.0350 - accuracy: 0.9860 - val_loss: 0.1156 - val_accuracy: 0.9620
# Epoch 16/100
# 23/23 [==============================] - 7s 305ms/step - loss: 0.0335 - accuracy: 0.9902 - val_loss: 0.0632 - val_accuracy: 0.9620
# Epoch 17/100
# 23/23 [==============================] - 7s 304ms/step - loss: 0.0344 - accuracy: 0.9860 - val_loss: 0.0514 - val_accuracy: 0.9747
# 3/3 [==============================] - 0s 39ms/step
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0514 - accuracy: 0.9747
# Epoch 1/100
# 23/23 [==============================] - 8s 330ms/step - loss: 0.0442 - accuracy: 0.9902 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 2/100
# 23/23 [==============================] - 7s 315ms/step - loss: 0.0552 - accuracy: 0.9818 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 3/100
# 23/23 [==============================] - 7s 314ms/step - loss: 0.0433 - accuracy: 0.9846 - val_loss: 0.2163 - val_accuracy: 0.9367
# Epoch 4/100
# 23/23 [==============================] - 7s 300ms/step - loss: 0.0317 - accuracy: 0.9874 - val_loss: 0.2345 - val_accuracy: 0.8987
# Epoch 5/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.0555 - accuracy: 0.9804 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 6/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.0260 - accuracy: 0.9902 - val_loss: 0.0596 - val_accuracy: 0.9747
# Epoch 7/100
# 23/23 [==============================] - 7s 300ms/step - loss: 0.0291 - accuracy: 0.9916 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 8/100
# 23/23 [==============================] - 7s 296ms/step - loss: 0.0392 - accuracy: 0.9874 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 9/100
# 23/23 [==============================] - 7s 305ms/step - loss: 0.0240 - accuracy: 0.9902 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 10/100
# 23/23 [==============================] - 7s 307ms/step - loss: 0.0152 - accuracy: 0.9930 - val_loss: 0.0276 - val_accuracy: 0.9873
# Epoch 11/100
# 23/23 [==============================] - 7s 298ms/step - loss: 0.0354 - accuracy: 0.9874 - val_loss: 0.6736 - val_accuracy: 0.8481
# Epoch 12/100
# 23/23 [==============================] - 7s 296ms/step - loss: 0.0468 - accuracy: 0.9860 - val_loss: 0.0240 - val_accuracy: 0.9873
# Epoch 13/100
# 23/23 [==============================] - 7s 292ms/step - loss: 0.0324 - accuracy: 0.9832 - val_loss: 0.0904 - val_accuracy: 0.9494
# Epoch 14/100
# 23/23 [==============================] - 7s 300ms/step - loss: 0.0752 - accuracy: 0.9818 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 15/100
# 23/23 [==============================] - 7s 307ms/step - loss: 0.0429 - accuracy: 0.9860 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 16/100
# 23/23 [==============================] - 7s 304ms/step - loss: 0.0363 - accuracy: 0.9846 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 17/100
# 23/23 [==============================] - 7s 302ms/step - loss: 0.0227 - accuracy: 0.9930 - val_loss: 0.0129 - val_accuracy: 0.9873
# Epoch 18/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.0424 - accuracy: 0.9888 - val_loss: 0.0054 - val_accuracy: 1.0000
# 3/3 [==============================] - 0s 37ms/step
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 1/100
# 23/23 [==============================] - 8s 313ms/step - loss: 0.0395 - accuracy: 0.9888 - val_loss: 0.0502 - val_accuracy: 0.9873
# Epoch 2/100
# 23/23 [==============================] - 7s 302ms/step - loss: 0.0404 - accuracy: 0.9846 - val_loss: 0.1069 - val_accuracy: 0.9494
# Epoch 3/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.0395 - accuracy: 0.9846 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 4/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.0351 - accuracy: 0.9874 - val_loss: 1.4855 - val_accuracy: 0.8354
# Epoch 5/100
# 23/23 [==============================] - 7s 297ms/step - loss: 0.0427 - accuracy: 0.9846 - val_loss: 0.6188 - val_accuracy: 0.8734
# Epoch 6/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.0181 - accuracy: 0.9944 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 7/100
# 23/23 [==============================] - 7s 307ms/step - loss: 0.0387 - accuracy: 0.9888 - val_loss: 0.0423 - val_accuracy: 0.9873
# Epoch 8/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.0536 - accuracy: 0.9874 - val_loss: 0.0262 - val_accuracy: 0.9873
# Epoch 9/100
# 23/23 [==============================] - 7s 287ms/step - loss: 0.0296 - accuracy: 0.9888 - val_loss: 0.8993 - val_accuracy: 0.8608
# Epoch 10/100
# 23/23 [==============================] - 7s 293ms/step - loss: 0.0221 - accuracy: 0.9930 - val_loss: 0.1032 - val_accuracy: 0.9494
# Epoch 11/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.0503 - accuracy: 0.9832 - val_loss: 0.5574 - val_accuracy: 0.8734
# Epoch 12/100
# 23/23 [==============================] - 7s 307ms/step - loss: 0.0676 - accuracy: 0.9846 - val_loss: 0.1455 - val_accuracy: 0.9494
# Epoch 13/100
# 23/23 [==============================] - 7s 311ms/step - loss: 0.0243 - accuracy: 0.9902 - val_loss: 0.3323 - val_accuracy: 0.8987
# Epoch 14/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.0287 - accuracy: 0.9874 - val_loss: 0.3266 - val_accuracy: 0.9241
# 3/3 [==============================] - 0s 39ms/step
# 3/3 [==============================] - 0s 34ms/step - loss: 0.3266 - accuracy: 0.9241
# Epoch 1/100
# 23/23 [==============================] - 8s 314ms/step - loss: 0.0193 - accuracy: 0.9930 - val_loss: 0.2848 - val_accuracy: 0.9494
# Epoch 2/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.0274 - accuracy: 0.9888 - val_loss: 0.1257 - val_accuracy: 0.9873
# Epoch 3/100
# 23/23 [==============================] - 7s 310ms/step - loss: 0.0451 - accuracy: 0.9846 - val_loss: 0.1713 - val_accuracy: 0.9747
# Epoch 4/100
# 23/23 [==============================] - 7s 315ms/step - loss: 0.0297 - accuracy: 0.9902 - val_loss: 0.2032 - val_accuracy: 0.9747
# Epoch 5/100
# 23/23 [==============================] - 7s 296ms/step - loss: 0.0384 - accuracy: 0.9874 - val_loss: 0.0641 - val_accuracy: 0.9747
# Epoch 6/100
# 23/23 [==============================] - 7s 295ms/step - loss: 0.0235 - accuracy: 0.9902 - val_loss: 0.9780 - val_accuracy: 0.8608
# Epoch 7/100
# 23/23 [==============================] - 7s 297ms/step - loss: 0.0198 - accuracy: 0.9930 - val_loss: 0.0608 - val_accuracy: 0.9873
# Epoch 8/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.0433 - accuracy: 0.9874 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 9/100
# 23/23 [==============================] - 7s 306ms/step - loss: 0.0486 - accuracy: 0.9818 - val_loss: 0.0058 - val_accuracy: 1.0000
# 3/3 [==============================] - 0s 39ms/step
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 1/100
# 23/23 [==============================] - 8s 319ms/step - loss: 0.0491 - accuracy: 0.9888 - val_loss: 3.5385e-04 - val_accuracy: 1.0000
# Epoch 2/100
# 23/23 [==============================] - 7s 305ms/step - loss: 0.0253 - accuracy: 0.9874 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 3/100
# 23/23 [==============================] - 7s 307ms/step - loss: 0.0478 - accuracy: 0.9790 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 4/100
# 23/23 [==============================] - 7s 297ms/step - loss: 0.0339 - accuracy: 0.9818 - val_loss: 0.0750 - val_accuracy: 0.9620
# Epoch 5/100
# 23/23 [==============================] - 7s 297ms/step - loss: 0.0703 - accuracy: 0.9790 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 6/100
# 23/23 [==============================] - 7s 287ms/step - loss: 0.0345 - accuracy: 0.9902 - val_loss: 0.0403 - val_accuracy: 0.9747
# Epoch 7/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.0216 - accuracy: 0.9916 - val_loss: 0.0254 - val_accuracy: 0.9873
# Epoch 8/100
# 23/23 [==============================] - 7s 296ms/step - loss: 0.0503 - accuracy: 0.9846 - val_loss: 0.0458 - val_accuracy: 0.9747
# Epoch 9/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.0516 - accuracy: 0.9832 - val_loss: 0.0354 - val_accuracy: 0.9873
# Epoch 10/100
# 23/23 [==============================] - 7s 292ms/step - loss: 0.0431 - accuracy: 0.9846 - val_loss: 0.0162 - val_accuracy: 0.9873
# Epoch 11/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.0559 - accuracy: 0.9832 - val_loss: 0.7550 - val_accuracy: 0.8608
# Epoch 12/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.0430 - accuracy: 0.9874 - val_loss: 0.0582 - val_accuracy: 0.9747
# Epoch 13/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.0470 - accuracy: 0.9832 - val_loss: 0.0210 - val_accuracy: 0.9873
# Epoch 14/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.0467 - accuracy: 0.9832 - val_loss: 0.0632 - val_accuracy: 0.9747
# Epoch 15/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.0204 - accuracy: 0.9916 - val_loss: 0.0685 - val_accuracy: 0.9620
# Epoch 16/100
# 23/23 [==============================] - 7s 297ms/step - loss: 0.0256 - accuracy: 0.9902 - val_loss: 5.9710e-05 - val_accuracy: 1.0000
# Epoch 17/100
# 23/23 [==============================] - 7s 300ms/step - loss: 0.0171 - accuracy: 0.9930 - val_loss: 1.7216e-04 - val_accuracy: 1.0000
# Epoch 18/100
# 23/23 [==============================] - 7s 298ms/step - loss: 0.0268 - accuracy: 0.9916 - val_loss: 0.9316 - val_accuracy: 0.7848
# Epoch 19/100
# 23/23 [==============================] - 7s 301ms/step - loss: 0.0126 - accuracy: 0.9972 - val_loss: 0.0939 - val_accuracy: 0.9620
# Epoch 20/100
# 23/23 [==============================] - 7s 300ms/step - loss: 0.0501 - accuracy: 0.9860 - val_loss: 0.0357 - val_accuracy: 0.9873
# Epoch 21/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.0404 - accuracy: 0.9860 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 22/100
# 23/23 [==============================] - 7s 295ms/step - loss: 0.0431 - accuracy: 0.9874 - val_loss: 0.0235 - val_accuracy: 0.9873
# Epoch 23/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.0362 - accuracy: 0.9888 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 24/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.0453 - accuracy: 0.9888 - val_loss: 0.0365 - val_accuracy: 0.9747
# Epoch 25/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.0125 - accuracy: 0.9972 - val_loss: 0.0337 - val_accuracy: 0.9747
# Epoch 26/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.0117 - accuracy: 0.9972 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 27/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.0165 - accuracy: 0.9944 - val_loss: 0.0138 - val_accuracy: 0.9873
# Epoch 28/100
# 23/23 [==============================] - 7s 299ms/step - loss: 0.0301 - accuracy: 0.9902 - val_loss: 9.8966e-04 - val_accuracy: 1.0000
# Epoch 29/100
# 23/23 [==============================] - 7s 317ms/step - loss: 0.0214 - accuracy: 0.9902 - val_loss: 0.0825 - val_accuracy: 0.9620
# Epoch 30/100
# 23/23 [==============================] - 7s 299ms/step - loss: 0.0612 - accuracy: 0.9846 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 31/100
# 23/23 [==============================] - 7s 304ms/step - loss: 0.0442 - accuracy: 0.9832 - val_loss: 0.1356 - val_accuracy: 0.9620
# Epoch 32/100
# 23/23 [==============================] - 7s 304ms/step - loss: 0.0437 - accuracy: 0.9874 - val_loss: 0.5203 - val_accuracy: 0.8228
# Epoch 33/100
# 23/23 [==============================] - 7s 297ms/step - loss: 0.0270 - accuracy: 0.9902 - val_loss: 0.7403 - val_accuracy: 0.7975
# Epoch 34/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.0657 - accuracy: 0.9846 - val_loss: 0.2066 - val_accuracy: 0.9241
# 3/3 [==============================] - 0s 39ms/step
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2066 - accuracy: 0.9241
# Epoch 1/100
# 23/23 [==============================] - 8s 325ms/step - loss: 0.0772 - accuracy: 0.9804 - val_loss: 0.2705 - val_accuracy: 0.9494
# Epoch 2/100
# 23/23 [==============================] - 7s 313ms/step - loss: 0.0912 - accuracy: 0.9748 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 3/100
# 23/23 [==============================] - 7s 308ms/step - loss: 0.0928 - accuracy: 0.9677 - val_loss: 0.1962 - val_accuracy: 0.9494
# Epoch 4/100
# 23/23 [==============================] - 7s 306ms/step - loss: 0.0658 - accuracy: 0.9804 - val_loss: 2.6248e-04 - val_accuracy: 1.0000
# Epoch 5/100
# 23/23 [==============================] - 7s 308ms/step - loss: 0.0431 - accuracy: 0.9902 - val_loss: 1.3933 - val_accuracy: 0.8354
# Epoch 6/100
# 23/23 [==============================] - 8s 321ms/step - loss: 0.0613 - accuracy: 0.9846 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 7/100
# 23/23 [==============================] - 7s 314ms/step - loss: 0.0414 - accuracy: 0.9902 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 8/100
# 23/23 [==============================] - 7s 305ms/step - loss: 0.0261 - accuracy: 0.9902 - val_loss: 5.3775e-04 - val_accuracy: 1.0000
# Epoch 9/100
# 23/23 [==============================] - 7s 307ms/step - loss: 0.0383 - accuracy: 0.9846 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 10/100
# 23/23 [==============================] - 8s 330ms/step - loss: 0.0207 - accuracy: 0.9930 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 11/100
# 23/23 [==============================] - 7s 316ms/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 12/100
# 23/23 [==============================] - 8s 336ms/step - loss: 0.0276 - accuracy: 0.9930 - val_loss: 0.1274 - val_accuracy: 0.9620
# Epoch 13/100
# 23/23 [==============================] - 8s 339ms/step - loss: 0.0324 - accuracy: 0.9860 - val_loss: 0.2154 - val_accuracy: 0.9494
# Epoch 14/100
# 23/23 [==============================] - 8s 342ms/step - loss: 0.0189 - accuracy: 0.9874 - val_loss: 0.0421 - val_accuracy: 0.9873
# Epoch 15/100
# 23/23 [==============================] - 8s 320ms/step - loss: 0.0437 - accuracy: 0.9902 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 16/100
# 23/23 [==============================] - 7s 317ms/step - loss: 0.0297 - accuracy: 0.9888 - val_loss: 0.0268 - val_accuracy: 0.9873
# Epoch 17/100
# 23/23 [==============================] - 8s 323ms/step - loss: 0.0320 - accuracy: 0.9916 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 18/100
# 23/23 [==============================] - 8s 329ms/step - loss: 0.0182 - accuracy: 0.9916 - val_loss: 0.1116 - val_accuracy: 0.9367
# Epoch 19/100
# 23/23 [==============================] - 8s 323ms/step - loss: 0.0616 - accuracy: 0.9804 - val_loss: 0.8237 - val_accuracy: 0.8608
# 3/3 [==============================] - 0s 42ms/step
# 3/3 [==============================] - 0s 37ms/step - loss: 0.8237 - accuracy: 0.8608
# [0.987500011920929, 0.9750000238418579, 1.0, 1.0, 0.9746835827827454, 1.0, 0.9240506291389465, 1.0, 0.9240506291389465, 0.8607594966888428] [0.054841548204422, 0.06252381205558777, 0.023368606343865395, 0.0177389495074749, 0.05143254995346069, 0.005378840025514364, 0.3265838325023651, 0.00580127676948905, 0.20657844841480255, 0.8236729502677917]
