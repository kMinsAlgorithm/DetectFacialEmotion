# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os,cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#matplotlib을 통해 보여줄 그래프의 크기를 직접 지정해 준것.
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import tensorflow as tf

from keras.utils import np_utils
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
from keras.models import Sequential
from keras.layers import *
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
import os
data_path = './Input/CK+48'
file_list = os.listdir(data_path)
file_list.remove('.DS_Store')

print("file list:",file_list)

# Any results you write to the current directory are saved as output

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.datasets import make_classification
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

#디렉토리에서 이미지를 추출하기

num_epoch=10

img_data_list=[]

labels = []
labeled = 0
img_count = 0
#우리가 파일을 만든 순서가 아닌 컴퓨터가 지가 읽는 순서대로 파일을 불러옴.
for dataset in file_list:
    img_one_cat_len = 0
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.        
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        input_img_resize=cv2.resize(input_img,(300,300),interpolation=cv2.INTER_LINEAR)
#         input_img_gray = cv2.cvtColor(input_img_resize, cv2.COLOR_RGB2GRAY)
        img_data_list.append(input_img_resize)
        img_one_cat_len +=1
    #라벨링 넘파이 배열 생성 
    for label in range(img_one_cat_len):
        labels.append(labeled)

    labeled += 1

img_data = np.array(img_data_list)
labels = np.array(labels)

#이미지 데이터 정규화

img_data = img_data.astype('float32')
img_data = img_data/255 #normalization
print(img_data.shape)

num_classes = len(file_list)

# 카테고리 리스트로 선언
names = file_list

#라벨 이름 리턴
def getLabel(labels): 
    return names[labels.index(1)]
def getLabel_Incoding(preds):
    index = np.argmax(preds)
    return names[index-1]    

# 훈련, 검증 데이터 셋 분리.

#원핫 인코딩 /  (파라미터 값, 0으로된 배열의 크기)
# 0: 1000000
# 1: 0100000
# 2: 0010000
#하나의 이미지에 대해 0과 1로 라벨링된(원핫인코딩된)배열을 리턴받음.
Y = np_utils.to_categorical(labels, num_classes)

#Shuffle the dataset
x,y = shuffle(img_data,Y, random_state=2)
# Split the dataset
# X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

#모델 생성 및 요약
# import creat_model as cm
def create_model(num_output):
    model = Sequential()
    input_shape=(300,300,3)
#     input_shape=(300,300)
    model.add(Conv2D(16, (3, 3), input_shape=input_shape, padding='same',kernel_initializer='he_normal', activation = 'relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3),padding='same',kernel_initializer='he_normal', activation = 'relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding='same',kernel_initializer='he_normal', activation = 'relu'))

    model.add(MaxPooling2D(pool_size=(2, 2)))

#     model.add(Conv2D(32, (3, 3),padding='same',kernel_initializer='he_normal', activation = 'relu'))

#     model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(16, (3, 3),padding='same',kernel_initializer='he_normal', activation = 'relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    model.add(Dense(128, kernel_initializer='he_normal', activation = 'relu'))
    model.add(Dropout(0.5))
#     model.add(Dense(128, kernel_initializer='he_normal', activation = 'relu'))
    model.add(Dense(num_output, activation = 'softmax'))

    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    
    return model

model_custom = create_model(num_classes)

model_custom.summary()

#Conduct k-Fold Cross-validation

from sklearn.model_selection import KFold

# kfold 교차 검증
# 데이터가 적은 데이터 셋에 대하여 정확도를 향상 시키기 위함.
# 이는 기존에 Training / Validation / Test 세개의 집단으로 분류하는것 보다 Training / Test로만 분류할때 학습 데이터 셋이 더 많기 때문.

# 5개의 폴드 세트로 분리하는 K Fold 객체와 폴드 세트별 정확도를 담을 리스트 객체 생성.
kf = KFold(n_splits=10, shuffle=False)

#Data Augmentation 기능 / 데이터 증강 기법
#모델의 성능을 높이면서 오버피팅을 극복하기 위해 학습 데이터의 다양성을 늘리기 위함.
#하나의 원본 이미지를 다양항 버전으로 만들어 학습시키는 것.
#대표적인 데이터 증강 기법으로는 원본 이미지를 수평 또는 수직 반전 시키는 방법, 회전시키는 방법, 일부를 자르는 방법,RGB채널 순서를 바꾸거나 
#픽셀값을 변경하여 원본 이미지의 색조를 변경시키는 것들이 있음.
#이러한 이미지 증강 기법을 tf.keras의 ImageDataGenerator 가 대신해줌.
#이 툴 이외에 Data Albumenation이나, ImgAug, Tensorflow Image Library 등 다양한 데이터 증강 기법 툴들이 있음.

from keras.preprocessing.image import ImageDataGenerator

# 이미지 증강법 1단계.ImageDataGenerator 객체(aug)를 생성하면서 증강을 수행할 유형들을 지정.
aug = ImageDataGenerator(
    rotation_range = 40,
    zoom_range = 0.2,
    horizontal_flip = True,
    fill_mode = 'nearest')

#Training Model 
BS = 8 # batch size
EPOCHS = 100 # epochs

result = []
scores_loss = []
scores_acc = []
k_no = 0

#Kfold 객체의 split()을 호출하면 폴드별 학습용, 검증용 테스트의 로우 인덱스를 array로 반환
#split()이 알아서 학습용 검증용 데이터를 나누어줌. 위에서 k=5라고 지정한 경우 for문이 5번 돌아 가면서 학습용, 검증용 데이터를 나누어 줌.
for train_index, test_index in kf.split(x):
    #Kfold 객채의 split()으로 반환된 인덱스를 이용해 학습용, 검증용 테스트 데이터를 추출함.
    X_Train,X_Test = x[train_index], x[test_index]
    Y_Train,Y_Test = y[train_index], y[test_index]

    # 최적의 모델을 저장할 경로
    file_path = "./weights_best_emotion_detect3.h5"
    # 콜백 함수. (체크포인트, 조기 종료 선언)
    checkpoint = ModelCheckpoint(file_path, monitor='loss', save_best_only=True, mode='min')
    early = EarlyStopping(monitor="loss", mode="min", patience=8)

    callbacks_list = [checkpoint, early]

    #이미지 증강법 2단계 aug.flow(X,y,batch_size=,shuffle=) : X(훈련 이미지),y(라벨), 이미지를 한번에 몇개 업로드 시킬지에 대한 배치 사이즈,데이터 셔플 유무
    #flow 메소드로 생성한 객체는 Numpy Array Iterator 객체로 우리가 흔히 아는 Python Iterator처럼 loop문이나 next()함수를 사용해 Iterator 안에 데이터를 하나씩 호출 가능.

    hist = model_custom.fit_generator(aug.flow(X_Train, Y_Train), epochs=EPOCHS,validation_data=(X_Test, Y_Test), callbacks=callbacks_list)
    # model.fit(X_Train, Y_Train, batch_size=batch_size, epochs=epochs, validation_data=(X_Test, Y_Test), verbose=1)
    
#     model_custom.load_weights(file_path)
    result.append(model_custom.predict(X_Test))
    score = model_custom.evaluate(X_Test,Y_Test)
    scores_loss.append(score[0])
    scores_acc.append(score[1])
    k_no+=1

print(scores_acc,scores_loss)
# Out:
# file list: ['happy', 'surprise', 'sadness', 'anger']
# Loaded the images of dataset-happy
#
# Loaded the images of dataset-surprise
#
# Loaded the images of dataset-sadness
#
# Loaded the images of dataset-anger
#
# (795, 300, 300, 3)
# Metal device set to: Apple M1 Pro
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 300, 300, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 150, 150, 16)     0
#  )
#
#  batch_normalization (BatchN  (None, 150, 150, 16)     64
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 37, 37, 32)        18464
#
#  max_pooling2d_3 (MaxPooling  (None, 18, 18, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 18, 18, 16)        4624
#
#  max_pooling2d_4 (MaxPooling  (None, 9, 9, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 1296)              0
#
#  dense (Dense)               (None, 128)               166016
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 229,780
# Trainable params: 229,748
# Non-trainable params: 32
# _________________________________________________________________
# 2022-11-30 02:32:15.492051: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-30 02:32:15.492497: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /var/folders/zh/v9f2b_v55ml9_yp9qr_69lk40000gn/T/ipykernel_34677/886616039.py:195: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model_custom.fit_generator(aug.flow(X_Train, Y_Train), epochs=EPOCHS,validation_data=(X_Test, Y_Test), callbacks=callbacks_list)
# Epoch 1/100
# 2022-11-30 02:32:16.562931: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-11-30 02:32:16.919643: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 23/23 [==============================] - 7s 246ms/step - loss: 1.3745 - accuracy: 0.3552 - val_loss: 1.3271 - val_accuracy: 0.4750
# Epoch 2/100
# 2022-11-30 02:32:23.134700: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 23/23 [==============================] - 5s 230ms/step - loss: 1.2178 - accuracy: 0.4559 - val_loss: 1.3297 - val_accuracy: 0.3875
# Epoch 3/100
# 23/23 [==============================] - 5s 224ms/step - loss: 1.0804 - accuracy: 0.5650 - val_loss: 1.0520 - val_accuracy: 0.6125
# Epoch 4/100
# 23/23 [==============================] - 5s 228ms/step - loss: 0.8741 - accuracy: 0.6587 - val_loss: 1.0975 - val_accuracy: 0.6625
# Epoch 5/100
# 23/23 [==============================] - 5s 227ms/step - loss: 0.8564 - accuracy: 0.6378 - val_loss: 0.9087 - val_accuracy: 0.7500
# Epoch 6/100
# 23/23 [==============================] - 5s 227ms/step - loss: 0.7150 - accuracy: 0.7175 - val_loss: 0.7934 - val_accuracy: 0.6125
# Epoch 7/100
# 23/23 [==============================] - 5s 231ms/step - loss: 0
100
# 23/23 [==============================] - 6s 244ms/step - loss: 0.0370 - accuracy: 0.9888 - val_loss: 0.0059 - val_accuracy: 1.0000
# 3/3 [==============================] - 0s 19ms/step
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 1/100
# 23/23 [==============================] - 6s 261ms/step - loss: 0.0332 - accuracy: 0.9888 - val_loss: 7.6668e-04 - val_accuracy: 1.0000
# Epoch 2/100
# 23/23 [==============================] - 6s 242ms/step - loss: 0.0406 - accuracy: 0.9804 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 3/100
# 23/23 [==============================] - 6s 237ms/step - loss: 0.0261 - accuracy: 0.9902 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 4/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0158 - accuracy: 0.9972 - val_loss: 4.5241e-04 - val_accuracy: 1.0000
# Epoch 5/100
# 23/23 [==============================] - 6s 244ms/step - loss: 0.0375 - accuracy: 0.9832 - val_loss: 0.0785 - val_accuracy: 0.9620
# Epoch 6/100
# 23/23 [==============================] - 6s 239ms/step - loss: 0.0685 - accuracy: 0.9832 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 7/100
# 23/23 [==============================] - 6s 250ms/step - loss: 0.0352 - accuracy: 0.9930 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 8/100
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0274 - accuracy: 0.9916 - val_loss: 0.0325 - val_accuracy: 0.9873
# Epoch 9/100
# 23/23 [==============================] - 6s 254ms/step - loss: 0.0427 - accuracy: 0.9832 - val_loss: 0.0295 - val_accuracy: 0.9873
# Epoch 10/100
# 23/23 [==============================] - 6s 251ms/step - loss: 0.0529 - accuracy: 0.9777 - val_loss: 0.0686 - val_accuracy: 0.9620
# Epoch 11/100
# 23/23 [==============================] - 6s 249ms/step - loss: 0.0473 - accuracy: 0.9818 - val_loss: 0.0347 - val_accuracy: 0.9747
# Epoch 12/100
# 23/23 [==============================] - 6s 273ms/step - loss: 0.0286 - accuracy: 0.9874 - val_loss: 0.0200 - val_accuracy: 1.0000
# 3/3 [==============================] - 0s 19ms/step
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0200 - accuracy: 1.0000
# [0.949999988079071, 0.9750000238418579, 0.987500011920929, 0.987500011920929, 0.9625000357627869, 0.9746835827827454, 0.9746835827827454, 0.9873418211936951, 1.0, 1.0] [0.12321261316537857, 0.055854570120573044, 0.06943058967590332, 0.03108428791165352, 0.10063695907592773, 0.11970704048871994, 0.044854290783405304, 0.03538031876087189, 0.005925118923187256, 0.020004747435450554]

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train','val'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model_custom.evaluate(X_Test,Y_Test)
# Out:
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0200 - accuracy: 1.0000
# [0.020004747435450554, 1.0]

# %% [markdown]
# # 이미지 인덱싱으로 지정하여 예측

# %%
preds= model_custom.predict(X_Test[1:2])
preds
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[5.8366801e-05, 9.9993777e-01, 3.8224812e-06, 1.3176533e-12]],
#       dtype=float32)

# %%
plt.imshow(X_Test[1:2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [163], line 1
# ----> 1 plt.imshow(X_Test[1:2])
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/pyplot.py:2611, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2605 @_copy_docstring_and_deprecators(Axes.imshow)
#    2606 def imshow(
#    2607         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    2608         alpha=None, vmin=None, vmax=None, origin=None, extent=None, *,
#    2609         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2610         resample=None, url=None, data=None, **kwargs):
# -> 2611     __ret = gca().imshow(
#    2612         X, cmap=cmap, norm=norm, aspect=aspect,
#    2613         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2614         vmax=vmax, origin=origin, extent=extent,
#    2615         interpolation_stage=interpolation_stage,
#    2616         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2617         url=url, **({"data": data} if data is not None else {}),
#    2618         **kwargs)
#    2619     sci(__ret)
#    2620     return __ret
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5572, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5564 self.set_aspect(aspect)
#    5565 im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    5566                       interpolation=interpolation, origin=origin,
#    5567                       extent=extent, filternorm=filternorm,
#    5568                       filterrad=filterrad, resample=resample,
#    5569                       interpolation_stage=interpolation_stage,
#    5570                       **kwargs)
# -> 5572 im.set_data(X)
#    5573 im.set_alpha(alpha)
#    5574 if im.get_clip_path() is None:
#    5575     # image does not already have clipping set, clip to axes patch
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/image.py:710, in _ImageBase.set_data(self, A)
#     706     self._A = self._A[:, :, 0]
#     708 if not (self._A.ndim == 2
#     709         or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 710     raise TypeError("Invalid shape {} for image data"
#     711                     .format(self._A.shape))
#     713 if self._A.ndim == 3:
#     714     # If the input data has values outside the valid range (after
#     715     # normalisation), we issue a warning and then clip X to the bounds
#     716     # - otherwise casting wraps extreme values, hiding outliers and
#     717     # making reliable interpretation impossible.
#     718     high = 255 if np.issubdtype(self._A.dtype, np.integer) else 1
#
# TypeError: Invalid shape (1, 300, 300, 3) for image data

# %% [markdown]
# # 이미지 경로로 지정하여 예측

# %%
# surprise
# img = cv2.imread('./Input/CK+48/surprise/croped_image190.jpg')
# img = cv2.imread('./Input/CK+48/surprise/croped_image76.jpg')
#sadness #얘는 구분됨.
# img = cv2.imread('./Input/CK+48/sadness/croped_image456.jpg')
# img = cv2.imread('./Input/CK+48/sadness/croped_image418.jpg')
#happy
# img = cv2.imread('./Input/CK+48/happy/croped_image38.jpg')
img = cv2.imread('./Input/CK+48/happy/S010_006_00000013.png')

#anger
# img = cv2.imread('./Input/CK+48/anger/croped_image114.jpg')
# img =cv2.resize(img,(300,300),interpolation=cv2.INTER_LINEAR)
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
preds= model_custom.predict(img.reshape(-1,300,300,3))
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# preds = model_custom.predict(cv2.resize(img_list[0:1],(300,300),interpolation=cv2.INTER_LINEAR))
# img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
# img.reshape(-1,300,300,1)
# img.shape
preds
# Out:
# 1/1 [==============================] - 0s 16ms/step
# array([[0., 0., 0., 1.]], dtype=float32)

# %%
# img.shape
plt.imshow(img)
# plt.imshow(X_Test[0:1].reshape(300,300,3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [147], line 2
#       1 # img.shape
# ----> 2 plt.imshow(img)
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/pyplot.py:2611, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2605 @_copy_docstring_and_deprecators(Axes.imshow)
#    2606 def imshow(
#    2607         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    2608         alpha=None, vmin=None, vmax=None, origin=None, extent=None, *,
#    2609         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2610         resample=None, url=None, data=None, **kwargs):
# -> 2611     __ret = gca().imshow(
#    2612         X, cmap=cmap, norm=norm, aspect=aspect,
#    2613         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2614         vmax=vmax, origin=origin, extent=extent,
#    2615         interpolation_stage=interpolation_stage,
#    2616         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2617         url=url, **({"data": data} if data is not None else {}),
#    2618         **kwargs)
#    2619     sci(__ret)
#    2620     return __ret
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5572, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5564 self.set_aspect(aspect)
#    5565 im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    5566                       interpolation=interpolation, origin=origin,
#    5567                       extent=extent, filternorm=filternorm,
#    5568                       filterrad=filterrad, resample=resample,
#    5569                       interpolation_stage=interpolation_stage,
#    5570                       **kwargs)
# -> 5572 im.set_data(X)
#    5573 im.set_alpha(alpha)
#    5574 if im.get_clip_path() is None:
#    5575     # image does not already have clipping set, clip to axes patch
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/matplotlib/image.py:701, in _ImageBase.set_data(self, A)
#     697 self._A = cbook.safe_masked_invalid(A, copy=True)
#     699 if (self._A.dtype != np.uint8 and
#     700         not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 701     raise TypeError("Image data of dtype {} cannot be converted to "
#     702                     "float".format(self._A.dtype))
#     704 if self._A.ndim == 3 and self._A.shape[-1] == 1:
#     705     # If just one dimension assume scalar and apply colormap
#     706     self._A = self._A[:, :, 0]
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
plt.bar(range(1,5), preds[0])
plt.xlabel('class')
plt.ylabel('prob.')
plt.show()

# %%
def getLabel_Incoding(preds):
    index = np.argmax(preds)
    print(index)
    return names[index]

# %%
getLabel_Incoding(preds)
# Out:
# 0
# 'happy'

# %%
plt.imshow(X_Test[0:1].reshape(64,64,3))
cv2.resize(input_img,(300,300),interpolation=cv2.INTER_LINEAR)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [243], line 1
# ----> 1 plt.imshow(X_Test[0:1].reshape(64,64,3))
#
# ValueError: cannot reshape array of size 270000 into shape (64,64,3)

# %%
plt.imshow(x[1])

# %%
y[1]
# Out:
# array([0., 0., 0., 0., 1.], dtype=float32)

# %%
print(getLabel(y[2]))
# Out:
# surprise

# %%
Y[0]
# Out:
# array([1., 0., 0., 0.], dtype=float32)

# %%
from keras.models import load_model
emotion_detect_model = load_model('weights_best_emotion_detect3.h5')

# %%
emotion_detect_model.summary()
# Out:
# Model: "sequential_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_117 (Conv2D)         (None, 64, 64, 16)        208
#
#  max_pooling2d_112 (MaxPooli  (None, 32, 32, 16)       0
#  ng2D)
#
#  conv2d_118 (Conv2D)         (None, 32, 32, 32)        2080
#
#  max_pooling2d_113 (MaxPooli  (None, 16, 16, 32)       0
#  ng2D)
#
#  conv2d_119 (Conv2D)         (None, 16, 16, 32)        4128
#
#  max_pooling2d_114 (MaxPooli  (None, 8, 8, 32)         0
#  ng2D)
#
#  conv2d_120 (Conv2D)         (None, 8, 8, 64)          8256
#
#  max_pooling2d_115 (MaxPooli  (None, 4, 4, 64)         0
#  ng2D)
#
#  conv2d_121 (Conv2D)         (None, 4, 4, 128)         32896
#
#  max_pooling2d_116 (MaxPooli  (None, 2, 2, 128)        0
#  ng2D)
#
#  flatten_36 (Flatten)        (None, 512)               0
#
#  dense_73 (Dense)            (None, 256)               131328
#
#  dense_74 (Dense)            (None, 128)               32896
#
#  dropout_31 (Dropout)        (None, 128)               0
#
#  dense_75 (Dense)            (None, 7)                 903
#
# =================================================================
# Total params: 212,695
# Trainable params: 212,695
# Non-trainable params: 0
# _________________________________________________________________

# %%
img = cv2.imread('./image/croped_image19.jpg')
preds= emotion_detect_model.predict(img.reshape(-1,64,64,3))
text = getLabel_Incoding(preds)
print(text)
# preds= emotion_detect_model.predict()
# Out:
# 1/1 [==============================] - 0s 135ms/step
# contempt
# 2022-11-20 02:06:16.970052: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
print(getLabel(y[2]))
# Out:
# fear

# %%
#happy
# crop = img[10:290,10:290]
#sadness
# crop = img[660:940,1630:1910]
#anger
# crop = img[1000:1280,1630:1910]
#surprise
# crop = img[10:290,1630:1910]
#disgust
# crop = img[320:600,10:290]
#contempt
# crop = img[320:600,345:625]

#fear
crop = img[1000:1280,10:290]

a = 'fear'
dst = cv2.resize(crop, (300, 300), interpolation=cv2.INTER_LINEAR) 
cv2.imwrite(f'./emoticon/{a}.jpg', dst)
# Out:
# True

# %%
# Out:
# file list: ['happy', 'contempt', 'fear', 'surprise', 'sadness', 'anger', 'disgust']
# Loaded the images of dataset-happy
#
# Loaded the images of dataset-contempt
#
# Loaded the images of dataset-fear
#
# Loaded the images of dataset-surprise
#
# Loaded the images of dataset-sadness
#
# Loaded the images of dataset-anger
#
# Loaded the images of dataset-disgust
#
# (981, 48, 48, 3)
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_74 (Conv2D)          (None, 48, 48, 6)         456
#
#  max_pooling2d_70 (MaxPoolin  (None, 24, 24, 6)        0
#  g2D)
#
#  conv2d_75 (Conv2D)          (None, 24, 24, 16)        2416
#
#  activation_20 (Activation)  (None, 24, 24, 16)        0
#
#  max_pooling2d_71 (MaxPoolin  (None, 12, 12, 16)       0
#  g2D)
#
#  conv2d_76 (Conv2D)          (None, 10, 10, 64)        9280
#
#  max_pooling2d_72 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  flatten_24 (Flatten)        (None, 1600)              0
#
#  dense_48 (Dense)            (None, 128)               204928
#
#  dropout_20 (Dropout)        (None, 128)               0
#
#  dense_49 (Dense)            (None, 7)                 903
#
# =================================================================
# Total params: 217,983
# Trainable params: 217,983
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_77 (Conv2D)          (None, 46, 46, 64)        1792
#
#  max_pooling2d_73 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_78 (Conv2D)          (None, 13, 13, 128)       73856
#
#  conv2d_79 (Conv2D)          (None, 11, 11, 256)       295168
#
#  max_pooling2d_74 (MaxPoolin  (None, 3, 3, 256)        0
#  g2D)
#
#  flatten_25 (Flatten)        (None, 2304)              0
#
#  dense_50 (Dense)            (None, 256)               590080
#
#  dense_51 (Dense)            (None, 7)                 1799
#
# =================================================================
# Total params: 962,695
# Trainable params: 962,695
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2022-11-20 00:47:41.640063: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In [138], line 157
#     153 model.summary()
#     155 model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
# --> 157 history = model.fit(train_generator, batch_size=8 , epochs=20, validation_data = (X_test, y_test), callbacks = [callbacks],shuffle=True)
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits' defined at (most recent call last):
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/traitlets/config/application.py", line 978, in launch_instance
#       app.start()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#       self._run_once()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#       handle._run()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2885, in run_cell
#       result = self._run_cell(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#       return runner(coro)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3139, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3318, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3378, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/zh/v9f2b_v55ml9_yp9qr_69lk40000gn/T/ipykernel_7464/1755166853.py", line 157, in <module>
#       history = model.fit(train_generator, batch_size=8 , epochs=20, validation_data = (X_test, y_test), callbacks = [callbacks],shuffle=True)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 994, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1052, in compute_loss
#       return self.compiled_loss(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 152, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 272, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 2084, in sparse_categorical_crossentropy
#       return backend.sparse_categorical_crossentropy(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/backend.py", line 5630, in sparse_categorical_crossentropy
#       res = tf.nn.sparse_softmax_cross_entropy_with_logits(
# Node: 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits'
# Detected at node 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits' defined at (most recent call last):
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/traitlets/config/application.py", line 978, in launch_instance
#       app.start()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#       self._run_once()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#       handle._run()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2885, in run_cell
#       result = self._run_cell(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#       return runner(coro)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3139, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3318, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3378, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/zh/v9f2b_v55ml9_yp9qr_69lk40000gn/T/ipykernel_7464/1755166853.py", line 157, in <module>
#       history = model.fit(train_generator, batch_size=8 , epochs=20, validation_data = (X_test, y_test), callbacks = [callbacks],shuffle=True)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 994, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/training.py", line 1052, in compute_loss
#       return self.compiled_loss(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/engine/compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 152, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 272, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/losses.py", line 2084, in sparse_categorical_crossentropy
#       return backend.sparse_categorical_crossentropy(
#     File "/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/keras/backend.py", line 5630, in sparse_categorical_crossentropy
#       res = tf.nn.sparse_softmax_cross_entropy_with_logits(
# Node: 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits'
# 2 root error(s) found.
#   (0) INVALID_ARGUMENT:  logits and labels must have the same first dimension, got logits shape [8,7] and labels shape [56]
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]]
# 	 [[Equal/_21]]
#   (1) INVALID_ARGUMENT:  logits and labels must have the same first dimension, got logits shape [8,7] and labels shape [56]
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_706677]

# %% [markdown]
# # 데이터셋의 이미지 크기 정보 알아오기

# %%
import os
import cv2
data_path = './Input/CK+48'
file_list = os.listdir(data_path)
# file_list.remove('./DS_Store')
print("file list:",file_list)

num_epoch=10

img_data_list=[]

data_dir_list = os.listdir(data_path)

#우리가 파일을 만든 순서가 아닌 컴퓨터가 지가 읽는 순서대로 파일을 불러옴.
for dataset in data_dir_list:
    if dataset in '.DS_Store':
            continue
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.        
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        print(input_img.shape)
#         input_img_resize=cv2.resize(input_img,(48,48))
#         img_data_list.append(input_img_resize)
# Out:
# file list: ['happy', '.DS_Store', 'contempt', 'fear', 'surprise', 'sadness', 'anger', 'disgust']
# Loaded the images of dataset-happy
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-contempt
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-fear
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-surprise
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-sadness
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-anger
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# Loaded the images of dataset-disgust
#
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)

# %%
additional_data_path = './image'
additional_data_list = os.listdir(additional_data_path)
for dataset in additional_data_list:
    img_list=os.listdir(additional_data_path+'/'+ dataset)
#     print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.        
        input_img=cv2.imread(additional_data_path + '/'+ dataset + '/'+ img )
        
        print(input_img.shape)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In [4], line 4
#       2 additional_data_list = os.listdir(additional_data_path)
#       3 for dataset in additional_data_list:
# ----> 4     img_list=os.listdir(additional_data_path+'/'+ dataset)
#       5 #     print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
#       6     for img in img_list:
#       7         #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.
#
# NotADirectoryError: [Errno 20] Not a directory: './image/croped_image817.jpg'

# %%
def show_40sample_images(X_train, y_train):
    # 이 데이터셋에 있는 샘플 이미지를 몇 개 출력해 보죠:
    n_rows = 4
    n_cols = 10
    plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
    for row in range(n_rows):
        for col in range(n_cols):
            index = n_cols * row + col
            plt.subplot(n_rows, n_cols, index + 1)
            plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
            plt.axis('off')
            plt.title(class_names[int(y_train[index])], fontsize=12)
    plt.subplots_adjust(wspace=0.2, hspace=0.5)
    plt.show()

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os,cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#matplotlib을 통해 보여줄 그래프의 크기를 직접 지정해 준것.
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import tensorflow as tf

from keras.utils import np_utils
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
from keras.models import Sequential
from keras.layers import *
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
import os
data_path = './Input/CK+48'
file_list = os.listdir(data_path)
file_list.remove('.DS_Store')

print("file list:",file_list)

# Any results you write to the current directory are saved as output

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.datasets import make_classification
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

#디렉토리에서 이미지를 추출하기

num_epoch=10

img_data_list=[]

labels = []
labeled = 0
img_count = 0
#우리가 파일을 만든 순서가 아닌 컴퓨터가 지가 읽는 순서대로 파일을 불러옴.
for dataset in file_list:
    img_one_cat_len = 0
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        #이미지를 해당 경로에서 하나씩 읽어와서 (48,48)사이즈로 읽어와 img_data_list라는 array에 저장.        
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        input_img_resize=cv2.resize(input_img,(300,300),interpolation=cv2.INTER_LINEAR)
#         input_img_gray = cv2.cvtColor(input_img_resize, cv2.COLOR_RGB2GRAY)
        img_data_list.append(input_img_resize)
        img_one_cat_len +=1
    #라벨링 넘파이 배열 생성 
    for label in range(img_one_cat_len):
        labels.append(labeled)

    labeled += 1

img_data = np.array(img_data_list)
labels = np.array(labels)

#이미지 데이터 정규화

img_data = img_data.astype('float32')
img_data = img_data/255 #normalization
print(img_data.shape)

num_classes = len(file_list)

# 카테고리 리스트로 선언
names = file_list

#라벨 이름 리턴
def getLabel(labels): 
    return names[labels.index(1)]
def getLabel_Incoding(preds):
    index = np.argmax(preds)
    return names[index-1]    

# 훈련, 검증 데이터 셋 분리.

#원핫 인코딩 /  (파라미터 값, 0으로된 배열의 크기)
# 0: 1000000
# 1: 0100000
# 2: 0010000
#하나의 이미지에 대해 0과 1로 라벨링된(원핫인코딩된)배열을 리턴받음.
Y = np_utils.to_categorical(labels, num_classes)

#Shuffle the dataset
x,y = shuffle(img_data,Y, random_state=2)
# Split the dataset
# X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

#모델 생성 및 요약

from keras.models import load_model
model_custom = load_model('weights_best_emotion_detect5.h5')

model_custom.summary()

#Conduct k-Fold Cross-validation

from sklearn.model_selection import KFold

# kfold 교차 검증
# 데이터가 적은 데이터 셋에 대하여 정확도를 향상 시키기 위함.
# 이는 기존에 Training / Validation / Test 세개의 집단으로 분류하는것 보다 Training / Test로만 분류할때 학습 데이터 셋이 더 많기 때문.

# 5개의 폴드 세트로 분리하는 K Fold 객체와 폴드 세트별 정확도를 담을 리스트 객체 생성.
kf = KFold(n_splits=10, shuffle=False)

#Data Augmentation 기능 / 데이터 증강 기법
#모델의 성능을 높이면서 오버피팅을 극복하기 위해 학습 데이터의 다양성을 늘리기 위함.
#하나의 원본 이미지를 다양항 버전으로 만들어 학습시키는 것.
#대표적인 데이터 증강 기법으로는 원본 이미지를 수평 또는 수직 반전 시키는 방법, 회전시키는 방법, 일부를 자르는 방법,RGB채널 순서를 바꾸거나 
#픽셀값을 변경하여 원본 이미지의 색조를 변경시키는 것들이 있음.
#이러한 이미지 증강 기법을 tf.keras의 ImageDataGenerator 가 대신해줌.
#이 툴 이외에 Data Albumenation이나, ImgAug, Tensorflow Image Library 등 다양한 데이터 증강 기법 툴들이 있음.

from keras.preprocessing.image import ImageDataGenerator

# 이미지 증강법 1단계.ImageDataGenerator 객체(aug)를 생성하면서 증강을 수행할 유형들을 지정.
aug = ImageDataGenerator(
    rotation_range = 40,
    zoom_range = 0.2,
    horizontal_flip = True,
    fill_mode = 'nearest')

#Training Model 
BS = 8 # batch size
EPOCHS = 100 # epochs

result = []
scores_loss = []
scores_acc = []
k_no = 0

#Kfold 객체의 split()을 호출하면 폴드별 학습용, 검증용 테스트의 로우 인덱스를 array로 반환
#split()이 알아서 학습용 검증용 데이터를 나누어줌. 위에서 k=5라고 지정한 경우 for문이 5번 돌아 가면서 학습용, 검증용 데이터를 나누어 줌.
for train_index, test_index in kf.split(x):
    #Kfold 객채의 split()으로 반환된 인덱스를 이용해 학습용, 검증용 테스트 데이터를 추출함.
    X_Train,X_Test = x[train_index], x[test_index]
    Y_Train,Y_Test = y[train_index], y[test_index]

    # 최적의 모델을 저장할 경로
    file_path = "./weights_best_emotion_detect4.h5"
    # 콜백 함수. (체크포인트, 조기 종료 선언)
    checkpoint = ModelCheckpoint(file_path, monitor='loss', save_best_only=True, mode='min')
    early = EarlyStopping(monitor="loss", mode="min", patience=8)

    callbacks_list = [checkpoint, early]

    #이미지 증강법 2단계 aug.flow(X,y,batch_size=,shuffle=) : X(훈련 이미지),y(라벨), 이미지를 한번에 몇개 업로드 시킬지에 대한 배치 사이즈,데이터 셔플 유무
    #flow 메소드로 생성한 객체는 Numpy Array Iterator 객체로 우리가 흔히 아는 Python Iterator처럼 loop문이나 next()함수를 사용해 Iterator 안에 데이터를 하나씩 호출 가능.

    hist = model_custom.fit_generator(aug.flow(X_Train, Y_Train), epochs=EPOCHS,validation_data=(X_Test, Y_Test), callbacks=callbacks_list)
    # model.fit(X_Train, Y_Train, batch_size=batch_size, epochs=epochs, validation_data=(X_Test, Y_Test), verbose=1)
    
#     model_custom.load_weights(file_path)
    result.append(model_custom.predict(X_Test))
    score = model_custom.evaluate(X_Test,Y_Test)
    scores_loss.append(score[0])
    scores_acc.append(score[1])
    k_no+=1

print(scores_acc,scores_loss)
# Out:
# file list: ['happy', 'surprise', 'sadness', 'anger']
# Loaded the images of dataset-happy
#
# Loaded the images of dataset-surprise
#
# Loaded the images of dataset-sadness
#
# Loaded the images of dataset-anger
#
# (792, 300, 300, 3)
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_28 (Conv2D)          (None, 300, 300, 32)      896
#
#  batch_normalization_28 (Bat  (None, 300, 300, 32)     128
#  chNormalization)
#
#  max_pooling2d_28 (MaxPoolin  (None, 150, 150, 32)     0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 150, 150, 64)      18496
#
#  batch_normalization_29 (Bat  (None, 150, 150, 64)     256
#  chNormalization)
#
#  max_pooling2d_29 (MaxPoolin  (None, 75, 75, 64)       0
#  g2D)
#
#  conv2d_30 (Conv2D)          (None, 75, 75, 32)        18464
#
#  batch_normalization_30 (Bat  (None, 75, 75, 32)       128
#  chNormalization)
#
#  max_pooling2d_30 (MaxPoolin  (None, 37, 37, 32)       0
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 37, 37, 16)        4624
#
#  batch_normalization_31 (Bat  (None, 37, 37, 16)       64
#  chNormalization)
#
#  max_pooling2d_31 (MaxPoolin  (None, 18, 18, 16)       0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 5184)              0
#
#  dense_12 (Dense)            (None, 256)               1327360
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 4)                 1028
#
# =================================================================
# Total params: 1,371,444
# Trainable params: 1,371,156
# Non-trainable params: 288
# _________________________________________________________________
# /var/folders/zh/v9f2b_v55ml9_yp9qr_69lk40000gn/T/ipykernel_94752/3873763211.py:163: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model_custom.fit_generator(aug.flow(X_Train, Y_Train), epochs=EPOCHS,validation_data=(X_Test, Y_Test), callbacks=callbacks_list)
# Epoch 1/100
# 2022-11-28 16:00:30.196967: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 23/23 [==============================] - ETA: 0s - loss: 0.2362 - accuracy: 0.9508
# 2022-11-28 16:00:39.486860: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 23/23 [==============================] - 10s 369ms/step - loss: 0.2362 - accuracy: 0.9508 - val_loss: 1.6029 - val_accuracy: 0.8750
# Epoch 2/100
# 23/23 [==============================] - 7s 293ms/step - loss: 0.2208 - accuracy: 0.9480 - val_loss: 1.1481 - val_accuracy: 0.7875
# Epoch 3/100
# 23/23 [==============================] - 7s 294ms/step - loss: 0.1593 - accuracy: 0.9382 - val_loss: 0.0874 - val_accuracy: 0.9750
# Epoch 4/100
# 23/23 [==============================] - 7s 290ms/step - loss: 0.1490 - accuracy: 0.9410 - val_loss: 0.0265 - val_accuracy: 0.9875
# Epoch 5/100
# 23/23 [==============================] - 7s 299ms/step - loss: 0.1226 - accuracy: 0.9522 - val_loss: 0.1053 - val_accuracy: 0.9750
# Epoch 6/100
# 23/23 [==============================] - 7s 289ms/step - loss: 0.1568 - accuracy: 0.9466 - val_loss: 0.7643 - val_accuracy: 0.8000
# Epoch 7/100
# 23/23 [==============================] - 7s 298ms/step - loss: 0.1450 - accuracy: 0.9480 - val_loss: 2.1368 - val_accuracy: 0.5750
# Epoch 8/100
# 23/23 [==============================] - 7s 295ms/step - loss: 0.1447 - accuracy: 0.9621 - val_loss: 0.3629 - val_accuracy: 0.8500
# Epoch 9/100
# 23/23 [==============================] - 7s 288ms/step - loss: 0.1357 - accuracy: 0.9494 - val_loss: 0.4958 - val_accuracy: 0.8500
# Epoch 10/100
# 23/23 [==============================] - 7s 291ms/step - loss: 0.0976 - accuracy: 0.9635 - val_loss: 0.1186 - val_accuracy: 0.9625
# Epoch 11/100
# 23/23 [==============================] - 7s 300ms/step - loss: 0.0564 - accuracy: 0.9789 - val_loss: 0.1240 - val_accuracy: 0.9625
# Epoch 12/100
# 23/23 [==============================] - 7s 293ms/step - loss: 0.0996 - accuracy: 0.9677 - val_loss: 0.0601 - val_accuracy: 0.9875
# Epoch 13/100
# 23/23 [==============================] - 7s 285ms/step - loss: 0.1128 - accuracy: 0.9621 - val_loss: 0.4559 - val_accuracy: 0.8750
# Epoch 14/100
# 23/23 [==============================] - 7s 285ms/step - loss: 0.0989 - accuracy: 0.9579 - val_loss: 0.6927 - val_accuracy: 0.8750
# Epoch 15/100
# 23/23 [==============================] - 7s 297ms/step - loss: 0.0769 - accuracy: 0.9677 - val_loss: 0.3925 - val_accuracy: 0.8125
# Epoch 16/100
# 23/23 [==============================] - 7s 286ms/step - loss: 0.0713 - accuracy: 0.9705 - val_loss: 0.1217 - val_accuracy: 0.9250
# Epoch 17/100
# 23/23 [==============================] - 7s 285ms/step - loss: 0.
- val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 18/100
# 23/23 [==============================] - 8s 329ms/step - loss: 0.0182 - accuracy: 0.9916 - val_loss: 0.1116 - val_accuracy: 0.9367
# Epoch 19/100
# 23/23 [==============================] - 8s 323ms/step - loss: 0.0616 - accuracy: 0.9804 - val_loss: 0.8237 - val_accuracy: 0.8608
# 3/3 [==============================] - 0s 42ms/step
# 3/3 [==============================] - 0s 37ms/step - loss: 0.8237 - accuracy: 0.8608
# [0.987500011920929, 0.9750000238418579, 1.0, 1.0, 0.9746835827827454, 1.0, 0.9240506291389465, 1.0, 0.9240506291389465, 0.8607594966888428] [0.054841548204422, 0.06252381205558777, 0.023368606343865395, 0.0177389495074749, 0.05143254995346069, 0.005378840025514364, 0.3265838325023651, 0.00580127676948905, 0.20657844841480255, 0.8236729502677917]

# %%
# Out:
# objc[94752]: Class CaptureDelegate is implemented in both /Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x15650e538) and /Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_videoio.3.4.16.dylib (0x2962cc860). One of the two will be used. Which one is undefined.
# objc[94752]: Class CVWindow is implemented in both /Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x15650e588) and /Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x285858a68). One of the two will be used. Which one is undefined.
# objc[94752]: Class CVView is implemented in both /Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x15650e5b0) and /Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x285858a90). One of the two will be used. Which one is undefined.
# objc[94752]: Class CVSlider is implemented in both /Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x15650e5d8) and /Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x285858ab8). One of the two will be used. Which one is undefined.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [164], line 2
#       1 import cv2
# ----> 2 import mediapipe as mp
#       3 mp_drawing = mp.solutions.drawing_utils
#       4 mp_drawing_styles = mp.solutions.drawing_styles
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/mediapipe/__init__.py:17
#       1 """Copyright 2019 - 2020 The MediaPipe Authors.
#       2
#       3 Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 limitations under the License.
#      14 """
#      16 from mediapipe.python import *
# ---> 17 import mediapipe.python.solutions as solutions
#      19 __version__ = '0.8.11'
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/mediapipe/python/solutions/__init__.py:17
#       1 # Copyright 2020 The MediaPipe Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 """MediaPipe Solutions Python API."""
# ---> 17 import mediapipe.python.solutions.drawing_styles
#      18 import mediapipe.python.solutions.drawing_utils
#      19 import mediapipe.python.solutions.face_detection
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/mediapipe/python/solutions/drawing_styles.py:20
#      18 from mediapipe.python.solutions import face_mesh_connections
#      19 from mediapipe.python.solutions import hands_connections
# ---> 20 from mediapipe.python.solutions.drawing_utils import DrawingSpec
#      21 from mediapipe.python.solutions.hands import HandLandmark
#      22 from mediapipe.python.solutions.pose import PoseLandmark
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/mediapipe/python/solutions/drawing_utils.py:25
#      22 import matplotlib.pyplot as plt
#      23 import numpy as np
# ---> 25 from mediapipe.framework.formats import detection_pb2
#      26 from mediapipe.framework.formats import location_data_pb2
#      27 from mediapipe.framework.formats import landmark_pb2
#
# File ~/miniforge3/envs/ml/lib/python3.10/site-packages/mediapipe/framework/formats/detection_pb2.py:5
#       1 # -*- coding: utf-8 -*-
#       2 # Generated by the protocol buffer compiler.  DO NOT EDIT!
#       3 # source: mediapipe/framework/formats/detection.proto
#       4 """Generated protocol buffer code."""
# ----> 5 from google.protobuf.internal import builder as _builder
#       6 from google.protobuf import descriptor as _descriptor
#       7 from google.protobuf import descriptor_pool as _descriptor_pool
#
# ImportError: cannot import name 'builder' from 'google.protobuf.internal' (/Users/kimmingyu/miniforge3/envs/ml/lib/python3.10/site-packages/google/protobuf/internal/__init__.py)

# %%
from keras.utils import plot_model

plot_model(model_custom,show_shapes=True , to_file = 'cnn_architecture.png', dpi=300)
